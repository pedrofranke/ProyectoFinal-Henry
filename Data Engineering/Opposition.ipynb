# %%
import pandas as pd
import numpy as np
from geopy import Nominatim

import warnings

# Desactivar todas las advertencias
warnings.filterwarnings("ignore")

# %%
df_rest = pd.read_parquet('Unification/df_restaurant.parquet')
df_rest.shape
# Out:
# (41562, 11)

# %%
mapping = {'Cafe': 1, 'Family': 2, 'Night': 3, 'European': 4, 'Vegetarian': 4, 'American':5, 'Asian':6, 'Central American':7,
           'South American':7, 'Fastfood':5, 'No Detail':2, 'African':6, 'Breakfast':1}

df_rest['numerical_category'] = df_rest['category'].map(mapping)

df_rest.head()
# Out:
#               business_id         business_name  category  avg_rating  \
# 0  MTSW4McQd7CbVtyjqoe9mw    St Honore Pastries      Cafe         4.0
# 1  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market    Family         4.5
# 2  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 3  sqSqqLy0sN8n2IZrAbzidQ        Domino's Pizza  American         3.5
# 4  Mjboz24M9NlBeiOJKLEd_Q      DeSandro on Main  European         3.0
#
#    review_count            address state          city postal_code   latitude  \
# 0            80        935 Race St    CA  Philadelphia       19107  39.955505
# 1           100      2575 E Bay Dr    FL         Largo       33771  27.916116
# 2            20     6625 E 82nd St    PA  Indianapolis       46250  39.904320
# 3             8  3001 Highway 31 W    CA   White House       37188  36.464747
# 4            41       4105 Main St    PA  Philadelphia       19127  40.022466
#
#    longitude  numerical_category
# 0 -75.155564                   1
# 1 -82.760461                   2
# 2 -86.053080                   1
# 3 -86.659187                   5
# 4 -75.218314                   4

# %%
# Obtener variables ficticias para la columna 'category'
dummies = pd.get_dummies(df_rest['numerical_category'])

# Concatenar las variables ficticias al DataFrame original
df_rest = pd.concat([df_rest, dummies], axis=1)
df_rest.head()
# Out:
#               business_id         business_name  category  avg_rating  \
# 0  MTSW4McQd7CbVtyjqoe9mw    St Honore Pastries      Cafe         4.0
# 1  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market    Family         4.5
# 2  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 3  sqSqqLy0sN8n2IZrAbzidQ        Domino's Pizza  American         3.5
# 4  Mjboz24M9NlBeiOJKLEd_Q      DeSandro on Main  European         3.0
#
#    review_count            address state          city postal_code   latitude  \
# 0            80        935 Race St    CA  Philadelphia       19107  39.955505
# 1           100      2575 E Bay Dr    FL         Largo       33771  27.916116
# 2            20     6625 E 82nd St    PA  Indianapolis       46250  39.904320
# 3             8  3001 Highway 31 W    CA   White House       37188  36.464747
# 4            41       4105 Main St    PA  Philadelphia       19127  40.022466
#
#    longitude  numerical_category      1      2      3      4      5      6  \
# 0 -75.155564                   1   True  False  False  False  False  False
# 1 -82.760461                   2  False   True  False  False  False  False
# 2 -86.053080                   1   True  False  False  False  False  False
# 3 -86.659187                   5  False  False  False  False   True  False
# 4 -75.218314                   4  False  False  False   True  False  False
#
#        7
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
def states(value):
  if value == 'CA':
    value = 'California'
  elif value == 'FL':
    value = 'Florida'
  elif value == 'PA':
    value = 'Pennsylvania'
  elif value == 'TX':
    value = 'Texas'
  return value

df_rest.state = df_rest.state.apply(states)

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

clusters = 34

# Selecciona las columnas relevantes
data = df_rest[['avg_rating']]
dummies = df_rest[[1, 2, 3, 4, 5, 6, 7]]  # Suponiendo que estas son tus columnas de dummies

# Escala la característica numérica (avg_rating)
scaler = StandardScaler()
scaled_avg_rating = scaler.fit_transform(data)

# Concatena la característica numérica escalada con las columnas de dummies
scaled_data = np.concatenate((scaled_avg_rating, dummies), axis=1)

# Entrenamiento del modelo K-Means
kmeans = KMeans(n_clusters=clusters, random_state=42)
df_rest['cluster'] = kmeans.fit_predict(scaled_data)

# %%
df_rest.drop(columns=['numerical_category',1,2,3,4,5,6,7],inplace=True)
df_rest.head()
# Out:
#               business_id         business_name  category  avg_rating  \
# 0  MTSW4McQd7CbVtyjqoe9mw    St Honore Pastries      Cafe         4.0
# 1  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market    Family         4.5
# 2  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 3  sqSqqLy0sN8n2IZrAbzidQ        Domino's Pizza  American         3.5
# 4  Mjboz24M9NlBeiOJKLEd_Q      DeSandro on Main  European         3.0
#
#    review_count            address         state          city postal_code  \
# 0            80        935 Race St    California  Philadelphia       19107
# 1           100      2575 E Bay Dr       Florida         Largo       33771
# 2            20     6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 3             8  3001 Highway 31 W    California   White House       37188
# 4            41       4105 Main St  Pennsylvania  Philadelphia       19127
#
#     latitude  longitude  cluster
# 0  39.955505 -75.155564       33
# 1  27.916116 -82.760461        0
# 2  39.904320 -86.053080       33
# 3  36.464747 -86.659187       16
# 4  40.022466 -75.218314       32

# %%
df_counties = pd.read_csv('ZIP-County.csv')
df_counties
# Out:
#          ZIP         COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003     Autauga County    AL        1001      H1
# 1      36006     Autauga County    AL        1001      H1
# 2      36067     Autauga County    AL        1001      H1
# 3      36066     Autauga County    AL        1001      H1
# 4      36703     Autauga County    AL        1001      H1
# ...      ...                ...   ...         ...     ...
# 52884    850   St. Croix Island    VI       78010      H4
# 52885    840   St. Croix Island    VI       78010      H4
# 52886    820   St. Croix Island    VI       78010      H4
# 52887    830    St. John Island    VI       78020      H4
# 52888    802  St. Thomas Island    VI       78030      H4
#
# [52889 rows x 5 columns]

# %%
df_counties.ZIP = df_counties.ZIP.apply(str)

# %%
df_counties.drop_duplicates(subset='ZIP',inplace=True)

# %%
df_merge = pd.merge(df_rest,df_counties[['ZIP','COUNTYNAME']],left_on='postal_code',right_on='ZIP',how='left')
df_merge.head()
# Out:
#               business_id         business_name  category  avg_rating  \
# 0  MTSW4McQd7CbVtyjqoe9mw    St Honore Pastries      Cafe         4.0
# 1  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market    Family         4.5
# 2  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 3  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 4  sqSqqLy0sN8n2IZrAbzidQ        Domino's Pizza  American         3.5
#
#    review_count            address         state          city postal_code  \
# 0            80        935 Race St    California  Philadelphia       19107
# 1           100      2575 E Bay Dr       Florida         Largo       33771
# 2            20     6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 3            20     6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 4             8  3001 Highway 31 W    California   White House       37188
#
#     latitude  longitude  cluster    ZIP           COUNTYNAME
# 0  39.955505 -75.155564       33  19107  Philadelphia County
# 1  27.916116 -82.760461        0  33771      Pinellas County
# 2  39.904320 -86.053080       33  46250      Hamilton County
# 3  39.904320 -86.053080       33  46250        Marion County
# 4  36.464747 -86.659187       16  37188     Robertson County

# %%
df_merge[df_merge.COUNTYNAME.isna()]
# Out:
#                                  business_id       business_name    category  \
# 29                    YR0nwxBOKk6DiLHNItfsBQ        Boston Pizza    American
# 31                    jcL_qaGJiappzpnn-ifSoA           Fat Jakks       Asian
# 50                    JfGfqCnk0-Tnf6PlahPUJQ      Burger Village    American
# 60                    fNssGWMjae-SUzyyGblspQ               Apron      Family
# 70                    SlLfWzeYOrVBxCd-0QILZQ   The Boiling House  Vegetarian
# ...                                      ...                 ...         ...
# 45122  0x808de6150ec03e61:0x25c5355734227bb6       Little Napoli    European
# 45171   0x80dd264734b149b3:0x2a98e839aea58d8  Phở Vie Restaurant       Asian
# 45430   0x88dd08e42284924d:0x892c66e14a264c9                IHOP    American
# 45611  0x80857dc4e456b0f9:0x7129701f58df0129           Osmanthus       Asian
# 45628  0x89ca52d06cb4121b:0x33736af1c5a6aa31              Hoss's      Family
#
#        avg_rating  review_count  \
# 29            3.5            14
# 31            4.0             8
# 50            4.0            10
# 60            4.5            24
# 70            4.0           238
# ...           ...           ...
# 45122         4.4           935
# 45171         4.0           297
# 45430         4.2          1787
# 45611         4.3           105
# 45628         4.2          1104
#
#                                                  address         state  \
# 29                                     200 St. Albert Rd  Pennsylvania
# 31                                 10126 - 107 Avenue NW       Florida
# 50                                6187 Currents Drive NW       Florida
# 60                                        47 E Kings Hwy       Florida
# 70                           1990 Marlton Pike E, Ste 10       Florida
# ...                                                  ...           ...
# 45122  Little Napoli, Dolores St, Carmel-By-The-Sea, ...    California
# 45171  Phở Vie Restaurant, 15440 Beach Blvd, Westmins...    California
# 45430  IHOP, 2850 Ridge Way, Lake Wales, FL 33859, Un...       Florida
# 45611  Osmanthus, 6048 College Ave, Oakland, CA 94618...    California
# 45628  Hoss's, 4308 Business 220, Bedford, PA 15522, ...  Pennsylvania
#
#                     city postal_code   latitude   longitude  cluster  ZIP  \
# 29             St Albert     T8N 5H9  53.625071 -113.616645       16  NaN
# 31              Edmonton     T5H 0V6  53.551551 -113.495155        2  NaN
# 50              Edmonton     T6W 0L9  53.436403 -113.604288        7  NaN
# 60           Haddonfield       08033  39.897107  -75.034226        0  NaN
# 70           Cherry Hill       08003  39.899661  -74.953300        5  NaN
# ...                  ...         ...        ...         ...      ...  ...
# 45122  Carmel-by-the-Sea       92921  36.554031 -121.922531       12  NaN
# 45171        Westminster       92644  33.737926 -117.988155        2  NaN
# 45430         Lake Wales       33977  27.961174  -81.623398        7  NaN
# 45611            Oakland       94168  37.849062 -122.252093       11  NaN
# 45628   Bedford Township           0  40.051369  -78.510567       23  NaN
#
#       COUNTYNAME
# 29           NaN
# 31           NaN
# 50           NaN
# 60           NaN
# 70           NaN
# ...          ...
# 45122        NaN
# 45171        NaN
# 45430        NaN
# 45611        NaN
# 45628        NaN
#
# [1900 rows x 14 columns]

# %%
from geopy import Nominatim

geolocator = Nominatim(user_agent='pef999@hotmail.com')

def zip(row):
    try:
        if pd.isna(row['COUNTYNAME']):
            address = geolocator.reverse((row['latitude'],row['longitude'])).raw['address']
            zip = address['postcode']
            country = address['country']
            string = country + ' Printed'
            row['ZIP'] = zip
            row['COUNTYNAME'] = string
        return row
    except:
        row['ZIP'] = 'Error'
        return row

# %%
df_merge = df_merge.apply(zip,axis=1)

# %%
df_merge[df_merge.COUNTYNAME.isna()]
# Out:
#                                  business_id              business_name  \
# 4800                  GXDyR18dh33vu4lgmFiuEw       A'Pizze Tuscan Grill
# 25854  0x8649b0e69f9442ef:0x40a536f0bde607d3      Redland Ballfield BBQ
# 38741  0x89c25a1b0cd3c8cb:0xe29a00ff230959b8              P.J. Clarke's
# 39446  0x8094f90050be4dcb:0x8a52470b825bc0f3                Chuck Wagon
# 40717  0x80be3dffaf1721d3:0x85df382562b75703  Amigos Mexican Restaurant
# 41131  0x80c2a3e3c883c457:0xae5fd9b1d21d56ae        Mastro's Ocean Club
# 45043  0x80db44cec54fbe4f:0x682c8ce6161e7c98             Little Beijing
# 45628  0x89ca52d06cb4121b:0x33736af1c5a6aa31                     Hoss's
#
#                category  avg_rating  review_count  \
# 4800           European         3.5            51
# 25854          American         4.7            36
# 38741          American         4.2          1684
# 39446            Family         4.6          1118
# 40717  Central American         4.2           276
# 41131            Family         4.5          1297
# 45043             Asian         4.4           137
# 45628            Family         4.2          1104
#
#                                                  address         state  \
# 4800                                120 Center Square Rd       Florida
# 25854  Redland Ballfield BBQ, hwy 64 & VZ County Road...         Texas
# 38741  P.J. Clarke's, 250 Vesey St, New York, NY 1028...      New York
# 39446  Chuck Wagon, 1203 Academy Ave, Sanger, CA 9365...    California
# 40717  Amigos Mexican Restaurant, 285 N Main St, Bish...    California
# 41131  Mastro's Ocean Club, 18412 Pacific Coast Hwy, ...    California
# 45043  Little Beijing, 1420 Beaumont Ave, Beaumont, C...    California
# 45628  Hoss's, 4308 Business 220, Bedford, PA 15522, ...  Pennsylvania
#
#                    city postal_code   latitude   longitude  cluster    ZIP  \
# 4800         Swedesboro       08085  39.737942  -75.328576       19  Error
# 25854           No Data           0  32.378490  -95.503570       21  Error
# 38741          New York           0  40.713711  -74.016239        7  Error
# 39446            Sanger           0  36.699852 -119.554766        0  Error
# 40717            Bishop           0  37.362931 -118.395612        6  Error
# 41131           Topanga           0  34.039687 -118.576133        0  Error
# 45043          Beaumont           0  33.947794 -116.975985       11  Error
# 45628  Bedford Township           0  40.051369  -78.510567       23  Error
#
#       COUNTYNAME
# 4800         NaN
# 25854        NaN
# 38741        NaN
# 39446        NaN
# 40717        NaN
# 41131        NaN
# 45043        NaN
# 45628        NaN

# %%
df_merge.loc[4800,'ZIP'] = '08085'
df_merge.loc[25854,'ZIP'] = '75754'
df_merge.loc[38741,'ZIP'] = '10281'
df_merge.loc[39446,'ZIP'] = '93657'
df_merge.loc[40717,'ZIP'] = '93514'
df_merge.loc[41131,'ZIP'] = '90265'
df_merge.loc[45043,'ZIP'] = '92223'
df_merge.loc[45628,'ZIP'] = '15522'

# %%
df_merge[df_merge.COUNTYNAME.apply(lambda x: 'Printed' in x if isinstance(x,str) else False)]
# Out:
#                                  business_id       business_name    category  \
# 29                    YR0nwxBOKk6DiLHNItfsBQ        Boston Pizza    American
# 31                    jcL_qaGJiappzpnn-ifSoA           Fat Jakks       Asian
# 50                    JfGfqCnk0-Tnf6PlahPUJQ      Burger Village    American
# 60                    fNssGWMjae-SUzyyGblspQ               Apron      Family
# 70                    SlLfWzeYOrVBxCd-0QILZQ   The Boiling House  Vegetarian
# ...                                      ...                 ...         ...
# 44983  0x808580b9c8e6d781:0xc66d155748e1a74b     Jane The Bakery   Breakfast
# 45122  0x808de6150ec03e61:0x25c5355734227bb6       Little Napoli    European
# 45171   0x80dd264734b149b3:0x2a98e839aea58d8  Phở Vie Restaurant       Asian
# 45430   0x88dd08e42284924d:0x892c66e14a264c9                IHOP    American
# 45611  0x80857dc4e456b0f9:0x7129701f58df0129           Osmanthus       Asian
#
#        avg_rating  review_count  \
# 29            3.5            14
# 31            4.0             8
# 50            4.0            10
# 60            4.5            24
# 70            4.0           238
# ...           ...           ...
# 44983         4.7           608
# 45122         4.4           935
# 45171         4.0           297
# 45430         4.2          1787
# 45611         4.3           105
#
#                                                  address         state  \
# 29                                     200 St. Albert Rd  Pennsylvania
# 31                                 10126 - 107 Avenue NW       Florida
# 50                                6187 Currents Drive NW       Florida
# 60                                        47 E Kings Hwy       Florida
# 70                           1990 Marlton Pike E, Ste 10       Florida
# ...                                                  ...           ...
# 44983  Jane The Bakery, 1881 Geary Blvd, San Francisc...    California
# 45122  Little Napoli, Dolores St, Carmel-By-The-Sea, ...    California
# 45171  Phở Vie Restaurant, 15440 Beach Blvd, Westmins...    California
# 45430  IHOP, 2850 Ridge Way, Lake Wales, FL 33859, Un...       Florida
# 45611  Osmanthus, 6048 College Ave, Oakland, CA 94618...    California
#
#                     city postal_code   latitude   longitude  cluster      ZIP  \
# 29             St Albert     T8N 5H9  53.625071 -113.616645       16  T8N 0P7
# 31              Edmonton     T5H 0V6  53.551551 -113.495155        2  T5H 4L4
# 50              Edmonton     T6W 0L9  53.436403 -113.604288        7  T6W 0L9
# 60           Haddonfield       08033  39.897107  -75.034226        0    08033
# 70           Cherry Hill       08003  39.899661  -74.953300        5    08003
# ...                  ...         ...        ...         ...      ...      ...
# 44983      San Francisco       95115  37.783744 -122.434276       27    95115
# 45122  Carmel-by-the-Sea       92921  36.554031 -121.922531       12    92921
# 45171        Westminster       92644  33.737926 -117.988155        2    92644
# 45430         Lake Wales       33977  27.961174  -81.623398        7    33977
# 45611            Oakland       94168  37.849062 -122.252093       11    94168
#
#                   COUNTYNAME
# 29            Canada Printed
# 31            Canada Printed
# 50            Canada Printed
# 60     United States Printed
# 70     United States Printed
# ...                      ...
# 44983  United States Printed
# 45122  United States Printed
# 45171  United States Printed
# 45430  United States Printed
# 45611  United States Printed
#
# [1892 rows x 14 columns]

# %%
df_merge = df_merge[df_merge.COUNTYNAME.apply(lambda x: 'Canada' not in x if isinstance(x,str) else True)]

# %%
df_merge.shape
# Out:
# (48065, 14)

# %%
df_merge.loc[4800,'postal_code'] = '08085'
df_merge.loc[25854,'postal_code'] = '75754'
df_merge.loc[38741,'postal_code'] = '10281'
df_merge.loc[39446,'postal_code'] = '93657'
df_merge.loc[40717,'postal_code'] = '93514'
df_merge.loc[41131,'postal_code'] = '90265'
df_merge.loc[45043,'postal_code'] = '92223'
df_merge.loc[45628,'postal_code'] = '15522'

# %%
df_merge = pd.merge(df_merge.drop(columns=['ZIP','COUNTYNAME']),df_counties[['ZIP','COUNTYNAME']],left_on='postal_code',right_on='ZIP',how='left')

# %%
df_merge.isna().sum()
# Out:
# business_id         0
# business_name       0
# category            0
# avg_rating          0
# review_count        0
# address             0
# state               0
# city                0
# postal_code         0
# latitude            0
# longitude           0
# cluster             0
# ZIP              1119
# COUNTYNAME       1119
# dtype: int64

# %%
def county(row):
    try:
        if pd.isna(row['COUNTYNAME']):
            address = geolocator.reverse((row['latitude'],row['longitude'])).raw['address']
            county = address['county']
            row['COUNTYNAME'] = county
        return row
    except:
        row['ZIP'] = 'Error'
        return row

# %%
df_merge = df_merge.apply(county,axis=1)

# %%
df_merge[df_merge.ZIP.isna()]
# Out:
#                                  business_id            business_name  \
# 75                    fNssGWMjae-SUzyyGblspQ                    Apron
# 87                    SlLfWzeYOrVBxCd-0QILZQ        The Boiling House
# 113                   KsDY9IYqvumohkp74w5i6A       Jersey Mike's Subs
# 115                   mYbEGFsRcA0tfUNSYcBJMA  Golden River Restaurant
# 116                   Mt1FB8hM4XTi3Tk4i0q5gQ           Nicola's Pizza
# ...                                      ...                      ...
# 59953  0x80857de82ea86dc7:0x205107e7c902f3f0           Rockridge Cafe
# 60170  0x808de6150ec03e61:0x25c5355734227bb6            Little Napoli
# 60223   0x80dd264734b149b3:0x2a98e839aea58d8       Phở Vie Restaurant
# 60538   0x88dd08e42284924d:0x892c66e14a264c9                     IHOP
# 60755  0x80857dc4e456b0f9:0x7129701f58df0129                Osmanthus
#
#          category  avg_rating  review_count  \
# 75         Family         4.5            24
# 87     Vegetarian         4.0           238
# 113      Fastfood         4.0            21
# 115      American         5.0             8
# 116      European         4.0            54
# ...           ...         ...           ...
# 59953    American         4.3           328
# 60170    European         4.4           935
# 60223       Asian         4.0           297
# 60538    American         4.2          1787
# 60755       Asian         4.3           105
#
#                                                  address       state  \
# 75                                        47 E Kings Hwy     Florida
# 87                           1990 Marlton Pike E, Ste 10     Florida
# 113                            910 Haddonfield-Berlin Rd     Florida
# 115                                 8 E Scott St, Ste 10     Florida
# 116                                      8 N Franklin St     Florida
# ...                                                  ...         ...
# 59953  Rockridge Cafe, 5492 College Ave, Oakland, CA ...  California
# 60170  Little Napoli, Dolores St, Carmel-By-The-Sea, ...  California
# 60223  Phở Vie Restaurant, 15440 Beach Blvd, Westmins...  California
# 60538  IHOP, 2850 Ridge Way, Lake Wales, FL 33859, Un...     Florida
# 60755  Osmanthus, 6048 College Ave, Oakland, CA 94618...  California
#
#                     city postal_code   latitude   longitude  cluster  ZIP  \
# 75           Haddonfield       08033  39.897107  -75.034226        0  NaN
# 87           Cherry Hill       08003  39.899661  -74.953300        5  NaN
# 113             Voorhees       08043  39.848349  -74.977130        7  NaN
# 115            Riverside       08075  40.037703  -74.959281       21  NaN
# 116         Lambertville       08530  40.366418  -74.941678        5  NaN
# ...                  ...         ...        ...         ...      ...  ...
# 59953            Oakland       94168  37.842317 -122.251453        7  NaN
# 60170  Carmel-by-the-Sea       92921  36.554031 -121.922531       12  NaN
# 60223        Westminster       92644  33.737926 -117.988155        2  NaN
# 60538         Lake Wales       33977  27.961174  -81.623398        7  NaN
# 60755            Oakland       94168  37.849062 -122.252093       11  NaN
#
#               COUNTYNAME
# 75         Camden County
# 87         Camden County
# 113        Camden County
# 115    Burlington County
# 116     Hunterdon County
# ...                  ...
# 59953     Alameda County
# 60170    Monterey County
# 60223      Orange County
# 60538        Polk County
# 60755     Alameda County
#
# [1114 rows x 14 columns]

# %%
df_rest = df_merge.drop(columns='ZIP')

# %%
df_rest.head()
# Out:
#               business_id         business_name category  avg_rating  \
# 0  MTSW4McQd7CbVtyjqoe9mw    St Honore Pastries     Cafe         4.0
# 1  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market   Family         4.5
# 2  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express     Cafe         4.0
# 3  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express     Cafe         4.0
# 4  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express     Cafe         4.0
#
#    review_count         address         state          city postal_code  \
# 0            80     935 Race St    California  Philadelphia       19107
# 1           100   2575 E Bay Dr       Florida         Largo       33771
# 2            20  6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 3            20  6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 4            20  6625 E 82nd St  Pennsylvania  Indianapolis       46250
#
#     latitude  longitude  cluster           COUNTYNAME
# 0  39.955505 -75.155564       33  Philadelphia County
# 1  27.916116 -82.760461        0      Pinellas County
# 2  39.904320 -86.053080       33      Hamilton County
# 3  39.904320 -86.053080       33        Marion County
# 4  39.904320 -86.053080       33      Hamilton County

# %%
df_merge.shape
# Out:
# (65167, 14)

# %%
df_merge.duplicated().sum()
# Out:
# 17331

# %%
df_merge.shape[0] - df_merge.duplicated().sum()
# Out:
# 47836

# %%
df_merge = df_merge.drop_duplicates()

# %%
df_merge.shape
# Out:
# (47836, 14)

# %%
df_merge.head()
# Out:
#               business_id         business_name  category  avg_rating  \
# 0  MTSW4McQd7CbVtyjqoe9mw    St Honore Pastries      Cafe         4.0
# 1  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market    Family         4.5
# 2  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 3  kfNv-JZpuN6TVNSO6hHdkw       Hibachi Express      Cafe         4.0
# 6  sqSqqLy0sN8n2IZrAbzidQ        Domino's Pizza  American         3.5
#
#    review_count            address         state          city postal_code  \
# 0            80        935 Race St    California  Philadelphia       19107
# 1           100      2575 E Bay Dr       Florida         Largo       33771
# 2            20     6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 3            20     6625 E 82nd St  Pennsylvania  Indianapolis       46250
# 6             8  3001 Highway 31 W    California   White House       37188
#
#     latitude  longitude  cluster    ZIP           COUNTYNAME
# 0  39.955505 -75.155564       33  19107  Philadelphia County
# 1  27.916116 -82.760461        0  33771      Pinellas County
# 2  39.904320 -86.053080       33  46250      Hamilton County
# 3  39.904320 -86.053080       33  46250        Marion County
# 6  36.464747 -86.659187       16  37188     Robertson County

# %%
df_rest = df_merge.drop(columns='ZIP')

# %%
df_rest['County-cluster_count'] = df_rest.groupby(['COUNTYNAME', 'cluster'])['COUNTYNAME'].transform('count')
df_rest['County_count'] = df_rest.groupby(['COUNTYNAME'])['COUNTYNAME'].transform('count')

# %%
df_rest['%_Competencia'] = df_rest['County-cluster_count']/df_rest['County_count']*100
df_rest.sort_values(by='%_Competencia',ascending=False).head(20)
# Out:
#                                  business_id  \
# 58930  0x86f85fd3a9de44b7:0x5a09dbfe01394d24
# 18308                 ifBUgOthmXRjrO3rmI8k6w
# 36795  0x87025e58e5ceb8bf:0x41b00346e4adc859
# 49057  0x86f8ba4240f65a57:0xf1e33cd9e7f733c4
# 43927  0x866825f740f430fb:0x63b65c6eaa0711b9
# 40678  0x87012afac47047b7:0x3e3bfdcdf37bba5f
# 14768                 qKtq_mAOMLBonDn73AKXzQ
# 23140  0x8638fe34bff40e07:0xd0c3a649e173a315
# 46834  0x86fe4334ed7711b7:0x46abba40ac5adff2
# 52658  0x87a84477754054b1:0x24c3a22236589341
# 43919  0x865f2ebbf1d4c885:0x45ab675095695485
# 56098  0x87aa5ef2b33eaa91:0xb4e4271b98777be7
# 57198  0x86fa1562df7507cd:0xee095cd323e22f4d
# 32401  0x8635fde5bee2700d:0x62d2dd32ec89959b
# 60731  0x89c2e15a3d65e37b:0x8fb935fcdc3e567f
# 45015  0x86580a913f07d963:0xd07a94245ef5f9ab
# 15590                 NcNvcaGgY_XwmnG-a-GYYg
# 44539  0x865f6968fd2ff11b:0x8252d67e6b7b89f3
# 48533  0x865d8b5a2107b483:0xe45017bc91c14c96
# 31311  0x87002aa9ce64b11b:0x450ef198323080da
#
#                                          business_name          category  \
# 58930                           The Windmill City Cafe         No Detail
# 18308                                   Grille Billy's          American
# 36795                             Panda Chinese Buffet             Asian
# 49057                         Stoneys BBQ and Catering          American
# 43927                         Castro's Cafe Restaurant         No Detail
# 40678                                  Brickstreet 200         No Detail
# 14768                                  Thai Phooket II             Asian
# 23140                               Wise Eats & Treats          American
# 46834                            Mama Jo's Steak House            Family
# 52658                                      Nana's Cafe          American
# 43919  Two Fat Boys BBQ now open as Canyon BBQ & Grill          American
# 56098                                  The Gettin Spot          American
# 57198                                     The Oil Ring         No Detail
# 32401                                    Bistro Neuf 9          European
# 60731                                    Namaste India             Asian
# 45015                                        El Corral          American
# 15590                                       Stir Crazy             Night
# 44539                               Little House Grill         No Detail
# 48533                                 The postal grill         No Detail
# 31311                                      Azteca Cafe  Central American
#
#        avg_rating  review_count  \
# 58930         4.2            64
# 18308         3.0             9
# 36795         3.5            28
# 49057         4.5            35
# 43927         4.5            36
# 40678         4.0            74
# 14768         4.0           192
# 23140         4.3            28
# 46834         4.1            28
# 52658         4.9            25
# 43919         4.5            97
# 56098         4.5            58
# 57198         4.0            25
# 32401         4.3            18
# 60731         4.5           186
# 45015         3.7            55
# 15590         3.5             6
# 44539         4.6            17
# 48533         4.7            27
# 31311         4.6            27
#
#                                                  address         state  \
# 58930  The Windmill City Cafe, 610 4th St, Sterling C...         Texas
# 18308                                 1701 Fairview Blvd  Pennsylvania
# 36795  Panda Chinese Buffet, 1820 W American Blvd, Mu...         Texas
# 49057  Stoneys BBQ and Catering, 1724 Hickory St, Col...         Texas
# 43927  Castro's Cafe Restaurant, 201 S Alamo St, Refu...         Texas
# 40678  Brickstreet 200, 200 Main St, Panhandle, TX 79068         Texas
# 14768                                 915 Rivergate Pkwy  Pennsylvania
# 23140  Wise Eats & Treats, 219 S Magnolia St, Woodvil...         Texas
# 46834  Mama Jo's Steak House, 1250 S 9th St, Slaton, ...         Texas
# 52658     Nana's Cafe, 101 S Young St, Follett, TX 79034         Texas
# 43919  Two Fat Boys BBQ now open as Canyon BBQ & Gril...         Texas
# 56098  The Gettin Spot, 1010 Houston St, Wellington, ...         Texas
# 57198    The Oil Ring, 1115 Andrews Hwy, Crane, TX 79731         Texas
# 32401                 Bistro Neuf 9, Pittsburg, TX 75686         Texas
# 60731  Namaste India, 44 Franklin Turnpike, Mahwah, N...      New York
# 45015      El Corral, 515 SW Main St, Eldorado, TX 76936         Texas
# 15590    Castleton Square Mall, 6020 E 82nd St, Ste 1500  Pennsylvania
# 44539  Little House Grill, 304 East Military US90, Br...         Texas
# 48533  The postal grill, 27148 TX-97, Fowlerton, TX 7...         Texas
# 31311  Azteca Cafe, 113 W California St, Floydada, TX...         Texas
#
#                 city postal_code   latitude   longitude  cluster  \
# 58930  Sterling City       76951  31.836659 -100.987682       23
# 18308       Fairview       37062  35.990983  -87.092953        1
# 36795       Muleshoe       79347  34.237087 -102.744601       28
# 49057  Colorado City       79512  32.404647 -100.860269       21
# 43927        Refugio       78377  28.303738  -97.275128        0
# 40678      Panhandle       79068  35.343032 -101.378788       23
# 14768  Goodletsville       37012  36.298126  -86.700302        2
# 23140      Woodville       75979  30.773648  -94.414333        7
# 46834         Slaton       79364  33.427201 -101.642636       23
# 52658        Follett       79034  36.433516 -100.138039       21
# 43919      Camp Wood       78833  29.669876 -100.012351       21
# 56098     Wellington       79095  34.853457 -100.204600       21
# 57198          Crane       79731  31.392330 -102.348222       23
# 32401      Pittsburg       75686  32.995631  -94.967776       12
# 60731         Mahwah        7430  41.104530  -74.148567       11
# 45015       Eldorado       76936  30.855459 -100.605172       16
# 15590   Indianapolis       46262  39.767909  -86.157875       24
# 44539  Brackettville       78832  29.308289 -100.416235        0
# 48533      Fowlerton       78021  28.465324  -98.811374       25
# 31311       Floydada       79235  33.984146 -101.335585       29
#
#               COUNTYNAME  County-cluster_count  County_count  %_Competencia
# 58930    Sterling County                   1.0           1.0          100.0
# 18308     Dickson County                   1.0           1.0          100.0
# 36795      Bailey County                   1.0           1.0          100.0
# 49057    Mitchell County                   1.0           1.0          100.0
# 43927     Refugio County                   1.0           1.0          100.0
# 40678      Carson County                   1.0           1.0          100.0
# 14768      DeKalb County                   1.0           1.0          100.0
# 23140       Tyler County                   1.0           1.0          100.0
# 46834        Lynn County                   1.0           1.0          100.0
# 52658    Lipscomb County                   1.0           1.0          100.0
# 43919        Real County                   1.0           1.0          100.0
# 56098   Childress County                   1.0           1.0          100.0
# 57198       Crane County                   1.0           1.0          100.0
# 32401        Camp County                   1.0           1.0          100.0
# 60731      Bergen County                   1.0           1.0          100.0
# 45015  Schleicher County                   1.0           1.0          100.0
# 15590             Marion                   1.0           1.0          100.0
# 44539      Kinney County                   1.0           1.0          100.0
# 48533    La Salle County                   1.0           1.0          100.0
# 31311       Floyd County                   1.0           1.0          100.0

# %%
df_rest.shape
# Out:
# (47836, 16)

# %%
df_rest[df_rest.County_count > 10].shape
# Out:
# (47023, 16)

# %%
def competencia(row):
    if row['County_count'] < 3:
        row['%_Competencia'] = 0
    else:
        row['%_Competencia'] = (row['County-cluster_count']/row['County_count']) *100
    return row

# %%
df_rest.shape
# Out:
# (47836, 16)

# %%
df_rest = df_rest[~df_rest.COUNTYNAME.isna()]
df_rest = df_rest.apply(competencia,axis=1)

# %%
df_rest.sort_values(by='%_Competencia',ascending=False).head()
# Out:
#                                  business_id               business_name  \
# 49817  0x809a87c9b203ffff:0x12b8e850f8273e47  Grumpy Jeff's Public House
# 31795  0x8650fbe839b91065:0xd799ff1b49cec5de                   Soda Shop
# 44527   0x809a7bbb932b6ca1:0xc34ed8ff87bb17a               Villa Privata
# 30546   0x86fb19e8b3781fcb:0x375c717a34e9c80       El Chuco Mexican Food
# 32259  0x865086a0deae3a25:0x44296765dfbc5525   Aroma of Hope Coffee Shop
#
#         category  avg_rating  review_count  \
# 49817  No Detail         4.8           138
# 31795       Cafe         4.8            33
# 44527  No Detail         4.7            38
# 30546  No Detail         4.3            56
# 32259       Cafe         4.7            18
#
#                                                  address       state  \
# 49817  Grumpy Jeff's Public House, 12 W Main St, Ione...  California
# 31795    Soda Shop, 107 N Houston St, Comanche, TX 76442       Texas
# 44527  Villa Privata, 1218 Jackson Gate Rd, Jackson, ...  California
# 30546  El Chuco Mexican Food, 841 TX-302, Kermit, TX ...       Texas
# 32259  Aroma of Hope Coffee Shop, next to Family Doll...       Texas
#
#               city postal_code   latitude   longitude  cluster  \
# 49817         Ione       95640  38.352519 -120.933466       25
# 31795     Comanche       76442  31.897749  -98.605382       27
# 44527      Jackson       95642  38.364627 -120.774068       25
# 30546       Kermit       79745  31.852301 -103.067642        0
# 32259  Goldthwaite       76844  31.450837  -98.569570       27
#
#            COUNTYNAME  County-cluster_count  County_count  %_Competencia
# 49817   Amador County                   2.0           3.0      66.666667
# 31795    Mills County                   2.0           3.0      66.666667
# 44527   Amador County                   2.0           3.0      66.666667
# 30546  Winkler County                   2.0           3.0      66.666667
# 32259    Mills County                   2.0           3.0      66.666667

# %%
df_rest.columns
# Out:
# Index(['business_id', 'business_name', 'category', 'avg_rating',
#        'review_count', 'address', 'state', 'city', 'postal_code', 'latitude',
#        'longitude', 'cluster', 'COUNTYNAME', 'County-cluster_count',
#        'County_count', '%_Competencia'],
#       dtype='object')

# %%
df_rest.drop(columns=['County_count','County-cluster_count'],inplace=True)

# %%
df_rest.describe()
# Out:
#          avg_rating  review_count      latitude     longitude       cluster  \
# count  47831.000000  47831.000000  47831.000000  47831.000000  47831.000000
# mean       3.983036    100.599235     36.308442    -89.396530     14.113295
# std        0.740331    242.718605      5.079590     16.523745      9.934404
# min        1.000000      5.000000     24.547407   -124.263391      0.000000
# 25%        3.600000     24.000000     32.260830    -97.669158      5.000000
# 50%        4.200000     44.000000     38.593022    -82.514307     12.000000
# 75%        4.500000     84.000000     40.339964    -75.257297     23.000000
# max        5.000000   7470.000000     44.990914    -71.919502     33.000000
#
#        %_Competencia
# count   47831.000000
# mean        6.279163
# std         4.927916
# min         0.000000
# 25%         3.061224
# 50%         4.972875
# 75%         7.854153
# max        66.666667

# %%
df_rest.shape
# Out:
# (47831, 14)

# %%
df_rest.COUNTYNAME.isna().sum()
# Out:
# 0

# %%
df_reviews = pd.read_parquet('Unification/df_reviews.parquet')

# %%
df_reviews
# Out:
#          review_id                 user_id  \
# 0                0  3-1va0IQfK-9tUMzfHWfTA
# 1                1  KQSRUu4Aapl0hG6eu2v8iw
# 2                2  qUfRCH5NUyRDsJfM6jA5PQ
# 3                3  0q2W3-ieBUJWD5TTLKi3Ug
# 4                4  z-yvbUGwFn8PAijEHdU_RA
# ...            ...                     ...
# 3903580    3903580   115681351373725195193
# 3903581    3903581   115300300663901754734
# 3903582    3903582   100925700082850645645
# 3903583    3903583   109106707670810407931
# 3903584    3903584   111294173214385569206
#
#                                    business_id  rating  year  month  \
# 0                       MTSW4McQd7CbVtyjqoe9mw     5.0  2018      5
# 1                       MTSW4McQd7CbVtyjqoe9mw     4.0  2018      3
# 2                       MTSW4McQd7CbVtyjqoe9mw     4.0  2017      4
# 3                       MTSW4McQd7CbVtyjqoe9mw     4.0  2016      4
# 4                       MTSW4McQd7CbVtyjqoe9mw     5.0  2018      3
# ...                                        ...     ...   ...    ...
# 3903580  0x865ca94e2edeb237:0xdfc44b585273f4c5     5.0  2021      1
# 3903581  0x865ca94e2edeb237:0xdfc44b585273f4c5     5.0  2020     12
# 3903582  0x865ca94e2edeb237:0xdfc44b585273f4c5     5.0  2019      9
# 3903583  0x865ca94e2edeb237:0xdfc44b585273f4c5     5.0  2020     12
# 3903584  0x865ca94e2edeb237:0xdfc44b585273f4c5     5.0  2019     10
#
#          sentiment_analysis
# 0                         5
# 1                         5
# 2                         5
# 3                         5
# 4                         4
# ...                     ...
# 3903580                   2
# 3903581                   2
# 3903582                   2
# 3903583                   2
# 3903584                   2
#
# [3903585 rows x 7 columns]

# %%
df_unified = pd.merge(df_reviews,df_rest,on='business_id',how='outer')

# %%
df_unified.isna().sum()
# Out:
# review_id                2599
# user_id                  2599
# business_id                 0
# rating                   2599
# year                     2599
# month                    2599
# sentiment_analysis       2599
# business_name         1388490
# category              1388490
# avg_rating            1388490
# review_count          1388490
# address               1388490
# state                 1388490
# city                  1388490
# postal_code           1388490
# latitude              1388490
# longitude             1388490
# cluster               1388490
# COUNTYNAME            1388490
# %_Competencia         1388490
# dtype: int64

# %%
df_unified.shape
# Out:
# (4312657, 20)

# %%
df_final = df_unified.dropna()

# %%
df_final.shape
# Out:
# (2921568, 20)

# %%
df_final.isna().sum()
# Out:
# review_id             0
# user_id               0
# business_id           0
# rating                0
# year                  0
# month                 0
# sentiment_analysis    0
# business_name         0
# category              0
# avg_rating            0
# review_count          0
# address               0
# state                 0
# city                  0
# postal_code           0
# latitude              0
# longitude             0
# cluster               0
# COUNTYNAME            0
# %_Competencia         0
# dtype: int64

# %%
df_final.head()
# Out:
#    review_id                 user_id             business_id  rating    year  \
# 0        0.0  3-1va0IQfK-9tUMzfHWfTA  MTSW4McQd7CbVtyjqoe9mw     5.0  2018.0
# 1        1.0  KQSRUu4Aapl0hG6eu2v8iw  MTSW4McQd7CbVtyjqoe9mw     4.0  2018.0
# 2        2.0  qUfRCH5NUyRDsJfM6jA5PQ  MTSW4McQd7CbVtyjqoe9mw     4.0  2017.0
# 3        3.0  0q2W3-ieBUJWD5TTLKi3Ug  MTSW4McQd7CbVtyjqoe9mw     4.0  2016.0
# 4        4.0  z-yvbUGwFn8PAijEHdU_RA  MTSW4McQd7CbVtyjqoe9mw     5.0  2018.0
#
#    month  sentiment_analysis       business_name category  avg_rating  \
# 0    5.0                 5.0  St Honore Pastries     Cafe         4.0
# 1    3.0                 5.0  St Honore Pastries     Cafe         4.0
# 2    4.0                 5.0  St Honore Pastries     Cafe         4.0
# 3    4.0                 5.0  St Honore Pastries     Cafe         4.0
# 4    3.0                 4.0  St Honore Pastries     Cafe         4.0
#
#    review_count      address       state          city postal_code   latitude  \
# 0          80.0  935 Race St  California  Philadelphia       19107  39.955505
# 1          80.0  935 Race St  California  Philadelphia       19107  39.955505
# 2          80.0  935 Race St  California  Philadelphia       19107  39.955505
# 3          80.0  935 Race St  California  Philadelphia       19107  39.955505
# 4          80.0  935 Race St  California  Philadelphia       19107  39.955505
#
#    longitude  cluster           COUNTYNAME  %_Competencia
# 0 -75.155564     33.0  Philadelphia County        3.96668
# 1 -75.155564     33.0  Philadelphia County        3.96668
# 2 -75.155564     33.0  Philadelphia County        3.96668
# 3 -75.155564     33.0  Philadelphia County        3.96668
# 4 -75.155564     33.0  Philadelphia County        3.96668

# %%
df_final.rename(columns={'COUNTYNAME':'county'},inplace=True)
df_final.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'rating', 'year', 'month',
#        'sentiment_analysis', 'business_name', 'category', 'avg_rating',
#        'review_count', 'address', 'state', 'city', 'postal_code', 'latitude',
#        'longitude', 'cluster', 'county', '%_Competencia'],
#       dtype='object')

# %%
df_final.rename(columns={'%_Competencia':'%_competition'},inplace=True)
df_final.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'rating', 'year', 'month',
#        'sentiment_analysis', 'business_name', 'category', 'avg_rating',
#        'review_count', 'address', 'state', 'city', 'postal_code', 'latitude',
#        'longitude', 'cluster', 'county', '%_competition'],
#       dtype='object')

# %%
clusters = {0:'Family/NoDetail',1:'American',2:'Asian',3:'Cafe/breakfast',4:'Latin America',5:'European',
            6:'Latin America',7:'American',8:'American',9:'Family/NoDetail',10:'Cafe/breakfast',11:'Asian',12:'European',
            13:'European',14:'Asian',15:'Family/NoDetail',16:'American',17:'Family',18:'Latin America',19:'European',
            20:'Cafe/breakfast',21:'American',22:'Central American',23:'Family/NoDetail',24:'Night',25:'Family/NoDetail',
            26:'Cafe/breakfast',27:'Cafe/breakfast',28:'Asian',29:'Latin American',30:'Cafe/breakfast',31:'American',
            32:'European',33:'Cafe/breakfast'}

df_rest['cluster_rating'] = df_rest.groupby('cluster')['avg_rating'].transform('mean')
df_rest['cluster_name'] = None

def cluster_name(row):
    row['cluster_name'] = str(round(row['cluster_rating'],1)) + ' ' + clusters[row['cluster']]
    return row

print(df_rest.shape[0])

df_rest = df_rest.apply(cluster_name,axis=1)

print(df_rest.shape[0])
# Out:
# 47831
# 47831

# %%
print(df_rest.cluster_name.unique())
# Out:
# ['4.0 Cafe/breakfast' '4.5 Family/NoDetail' '3.6 American' '3.0 European'
#  '2.3 American' '4.1 American' '3.5 European' '4.1 Family/NoDetail'
#  '3.6 Family/NoDetail' '4.0 European' '4.0 Asian' '1.4 American'
#  '3.0 American' '2.3 European' '1.4 Cafe/breakfast' '3.5 Latin America'
#  '4.4 Latin America' '4.6 American' '3.5 Asian' '4.5 Cafe/breakfast'
#  '2.2 Family' '4.0 Latin America' '2.7 Central American'
#  '3.0 Cafe/breakfast' '4.5 Asian' '3.0 Family/NoDetail'
#  '4.8 Family/NoDetail' '4.5 European' '2.2 Cafe/breakfast' '2.8 Asian'
#  '4.8 Cafe/breakfast' '4.7 Latin American' '3.5 Cafe/breakfast'
#  '4.3 Night']

# %%
df_rest.columns
# Out:
# Index(['business_id', 'business_name', 'category', 'avg_rating',
#        'review_count', 'address', 'state', 'city', 'postal_code', 'latitude',
#        'longitude', 'cluster', 'COUNTYNAME', '%_Competencia', 'cluster_rating',
#        'cluster_name'],
#       dtype='object')

# %%
print(df_final.shape)
state_bounds = {
    'Florida': {'lat_min': 24.396308, 'lat_max': 31.000968, 'long_min': -87.634643, 'long_max': -80.031362},
    'California': {'lat_min': 32.534156, 'lat_max': 42.009518, 'long_min': -124.409591, 'long_max': -114.131211},
    'Pennsylvania': {'lat_min': 39.719800, 'lat_max': 42.269179, 'long_min': -80.519891, 'long_max': -74.689516},
    'New York': {'lat_min': 40.477399, 'lat_max': 45.015850, 'long_min': -79.762152, 'long_max': -71.856214},
    'Texas': {'lat_min': 25.837377, 'lat_max': 36.500704, 'long_min': -106.645646, 'long_max': -93.508292}
}
# Out:
# (2251808, 20)

# %%
def is_within_bounds(row):
    for bounds in state_bounds.values():
        if bounds['lat_min'] <= row['latitude'] <= bounds['lat_max'] and bounds['long_min'] <= row['longitude'] <= bounds['long_max']:
            return True
    return False

# %%
df_final.to_parquet('Unification/df_unified.parquet')

# %%
df_rest.rename(columns={'%_Competencia':'%_competition'},inplace=True)
df_rest.rename(columns={'COUNTYNAME':'county'},inplace=True)

# %%
print(df_rest.shape)
df_rest = df_rest[df_rest.apply(is_within_bounds,axis=1)]
print(df_rest.shape)
# Out:
# (34553, 16)
# (34553, 16)

# %%
df_rest.to_parquet('Unification/df_restaurants.parquet')

# %%
keep = df_reviews.columns.tolist()

df_reviews = df_final[keep]

# %%
df_reviews.shape
# Out:
# (2921568, 7)

# %%
df_reviews.head()
# Out:
#    review_id                 user_id             business_id  rating    year  \
# 0        0.0  3-1va0IQfK-9tUMzfHWfTA  MTSW4McQd7CbVtyjqoe9mw     5.0  2018.0
# 1        1.0  KQSRUu4Aapl0hG6eu2v8iw  MTSW4McQd7CbVtyjqoe9mw     4.0  2018.0
# 2        2.0  qUfRCH5NUyRDsJfM6jA5PQ  MTSW4McQd7CbVtyjqoe9mw     4.0  2017.0
# 3        3.0  0q2W3-ieBUJWD5TTLKi3Ug  MTSW4McQd7CbVtyjqoe9mw     4.0  2016.0
# 4        4.0  z-yvbUGwFn8PAijEHdU_RA  MTSW4McQd7CbVtyjqoe9mw     5.0  2018.0
#
#    month  sentiment_analysis
# 0    5.0                 5.0
# 1    3.0                 5.0
# 2    4.0                 5.0
# 3    4.0                 5.0
# 4    3.0                 4.0

# %%
df_reviews.to_parquet('Unification/df_reviews.parquet')

# %%
['review_id','user_id','business_id','rating','year','month','sentiment_analysis']
