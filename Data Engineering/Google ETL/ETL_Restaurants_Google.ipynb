# %% [markdown]
# ## Overview
#
# This notebook outlines the ETL process for restaurant metadata, focusing on the integration of `metadata-places` files and `customer reviews` from each state. It delves into each stage of the workflow, from data extraction and transformation to the final loading phase. Throughout, I'll detail the techniques employed and the rationale behind each step, aiming to construct a comprehensive and insightful dataset that sheds light on the intricacies of the restaurant industry across various regions.

# %%
import os
import re
import json
import pandas as pd
import concurrent.futures
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from geopy import Nominatim

# %% [markdown]
# ## Loading Data
#
# In this phase, we focus on preparing and integrating the restaurant metadata with reviews. The process unfolds as follows:
#
# - **`Define Paths`**: We start by specifying the directories for both the metadata of places and the reviews from various states, ensuring a structured approach to data handling.
#
# - **`Collect GMap IDs`**: A function is employed to traverse through state review directories, collecting unique Google Maps IDs. This step is crucial for correlating reviews with the corresponding restaurant metadata.
#
# - **`Filter Metadata`**: With the collected GMap IDs, we filter the comprehensive metadata to retain only those entries that match our review dataset. This filtration ensures our dataset is precise and relevant to the analysis.
#
# - **`Data Integration`**: The final step involves integrating the filtered metadata with the state-specific reviews, enriching our dataset with a wealth of information for in-depth analysis. This integrated dataset forms the backbone of our ETL process, ready for transformation and analysis.
#
# - **`Filter by Restaurant`**: Further refine the dataset by filtering for entries that specifically relate to food services such as restaurants, cafes, and eateries, excluding non-food-related establishments. This is achieved by matching against a predefined list of food-related keywords and exclusions to ensure the dataset is strictly relevant to the restaurant analysis.
#
# - **`Check Categories`**: After filtering, we examine the categories of the remaining entries to validate the effectiveness of our filtering criteria and to understand the distribution of restaurant types within our dataset. This step provides insight into the variety of dining establishments covered in our analysis and helps identify any potential areas for further refinement in our data selection criteria.
#
# **Note**: This targeted approach was chosen to ensure efficiency and relevance in our analysis. By focusing only on restaurants from each state that will be used in the analysis, and further refining the selection to include only food-related establishments, we avoid the unnecessary loading and processing of extraneous data. This method streamlines our data preparation phase, ensuring that only pertinent data is considered, thereby optimizing the analysis process and conserving computational resources.

# %% [markdown]
# **Defining paths**

# %%
metadata_places_path = '../data/raw/Google Maps/metadata-places/'
state_review_paths = {
    'New York': '../data/raw/Google Maps/State Review/review-New_York/',
    'California': '../data/raw/Google Maps/State Review/review-California/',
    'Florida': '../data/raw/Google Maps/State Review/review-Florida/',
    'Pennsylvania': '../data/raw/Google Maps/State Review/review-Pennsylvania/',
    'Texas': '../data/raw/Google Maps/State Review/review-Texas/'
}

# %% [markdown]
# **Collect GMap IDs**

# %%
def collect_gmap_ids_from_reviews(state_review_paths):
    state_gmap_ids = {}
    for state, state_path in state_review_paths.items():
        state_gmap_ids[state] = set()
        # Iterate over each JSON file
        for filename in os.listdir(state_path):
            file_path = os.path.join(state_path, filename)
            with open(file_path, 'r') as file:
                for line in file:
                    review_data = json.loads(line)
                    state_gmap_ids[state].add(review_data['gmap_id'])
    return state_gmap_ids

# %% [markdown]
# **Filter Metadata**

# %%
def filter_metadata_places(metadata_places_path, state_gmap_ids):
    filtered_metadata = []
    for filename in os.listdir(metadata_places_path):
        file_path = os.path.join(metadata_places_path, filename)
        with open(file_path, 'r') as file:
            for line in file:
                place_data = json.loads(line)
                for state, gmap_ids in state_gmap_ids.items():
                    if place_data['gmap_id'] in gmap_ids:
                        place_data['state'] = state 
                        filtered_metadata.append(place_data)
                        break  # Break to avoid adding the same place under multiple states
    return filtered_metadata

# %% [markdown]
# **Data Integration**

# %%
# Step 1: Collect GMap IDs from state reviews with state information
state_gmap_ids = collect_gmap_ids_from_reviews(state_review_paths)

# Step 2: Filter metadata places based on collected GMap IDs and include state information
filtered_metadata = filter_metadata_places(metadata_places_path, state_gmap_ids)

# Step 3: Convert the filtered metadata to a DataFrame
df_filtered_metadata = pd.DataFrame(filtered_metadata)

# %%
df_filtered_metadata.tail()
# Out:
#                               name  \
# 324132       Audiomotive Creations
# 324133       The Alibi Bar & Grill
# 324134  Peacemaker Brewing Company
# 324135  SVS Vision Optical Centers
# 324136    House of Gourmet -- 食全食美
#
#                                                   address  \
# 324132  Audiomotive Creations, 1167 Niagara Falls Blvd...
# 324133  The Alibi Bar & Grill, 5822 Camp Rd, Hamburg, ...
# 324134  Peacemaker Brewing Company, 39 Coach St, Canan...
# 324135  SVS Vision Optical Centers, 1551 Niagara Falls...
# 324136  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
#
#                                       gmap_id description   latitude  \
# 324132  0x89d3726f24abe7a1:0xa756f654e5f0ea9c        None  42.986004
# 324133  0x89d304cb1436ea91:0xeb8ec964c0277a1e        None  42.728979
# 324134  0x89d126876236a7ad:0x8271b070396653b1        None  42.884818
# 324135  0x89d3721399f576df:0xe572aaa0d5ae28fc        None  42.997026
# 324136   0x89d373386b718fff:0xf82c90ef48e7b23        None  42.980251
#
#         longitude                                           category  \
# 324132 -78.822423              [Auto parts store, Electronics store]
# 324133 -78.836644                                              [Bar]
# 324134 -77.281542                                          [Brewery]
# 324135 -78.821580  [Eye care center, Contact lenses supplier, Opt...
# 324136 -78.827337           [Chinese restaurant, Sichuan restaurant]
#
#         avg_rating  num_of_reviews price  \
# 324132         4.9             548  None
# 324133         4.3             155     $
# 324134         4.8              68  None
# 324135         4.7              68  None
# 324136         4.3              58  None
#
#                                                     hours  \
# 324132  [[Saturday, 9AM–6PM], [Sunday, Closed], [Monda...
# 324133  [[Saturday, 12PM–4AM], [Sunday, 12PM–4AM], [Mo...
# 324134  [[Saturday, 12–10PM], [Sunday, 12–5PM], [Monda...
# 324135  [[Saturday, 9AM–1PM], [Sunday, Closed], [Monda...
# 324136  [[Saturday, 11:15AM–9:45PM], [Sunday, 11:15AM–...
#
#                                                      MISC     state  \
# 324132                                               None  New York
# 324133  {'Service options': ['Outdoor seating', 'Takeo...  New York
# 324134  {'From the business': ['Identifies as veteran-...  New York
# 324135  {'Highlights': ['LGBTQ friendly', 'Transgender...  New York
# 324136  {'Service options': ['Delivery', 'Takeout', 'D...  New York
#
#                                          relative_results  \
# 324132  [0x89d36814d72ff6b5:0x9f609a9ca26e5db1, 0x89d3...
# 324133  [0x89d31ad0f3d9db0b:0x975a9c5fcea9860d, 0x89d3...
# 324134  [0x89d1269180ea2eef:0x956e4a0ddb33852b, 0x89d1...
# 324135  [0x89d37250fe70683f:0x321b9ff0973f91a4, 0x89d3...
# 324136  [0x89d3731867671331:0x643f6dd3ba475c6e, 0x89d3...
#
#                                                       url
# 324132  https://www.google.com/maps/place//data=!4m2!3...
# 324133  https://www.google.com/maps/place//data=!4m2!3...
# 324134  https://www.google.com/maps/place//data=!4m2!3...
# 324135  https://www.google.com/maps/place//data=!4m2!3...
# 324136  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# **Filter by restaurant**:
# - Updated keywords and exclusions to keep those who are only related to restaurants.
# - Created function to apply and filter

# %%
food_keywords = [
    'restaurant', 'cafe', '\\bfood\\b', 'dining', 'eatery', 'bistro', 'bakery',
    'grill', 'kitchen', 'pizzeria', 'steakhouse', 'sushi', 'tavern', 'diner'
]

exclusions = [
    'supplier','ATM','gas station', 'school', 'bank', 'area', 'company', 'broker', 'bark', 'stool', 'dart',
    'store', 'shop', 'bar', 'lounge', 'venue', 'service', 'club', 'remodeler', 'boutique',
    'market', 'pharmacy', 'furniture', 'grocery', 'hardware', 'book', 'garden', 'home', 'office', 
    'electronics', 'clothing', 'gift', 'toy', 'jewelry', 'florist', 'repair', 'maintenance',
    'construction', 'contractor', 'installer', 'supplier', 'wholesaler', 'retailer', 'distributor', 
    'manufacturer', 'producer', 'facility', 'center', 'park', 'gallery', 'studio', 'salon', 'spa',
    'gym', 'fitness', 'health', 'wellness', 'boutique', 'event', 'entertainment', 'amusement', 
    'recreation', 'cultural', 'education', 'tutoring', 'learning', 'training', 'consultant', 
    'counseling', 'legal', 'financial', 'insurance', 'real estate', 'accommodation', 'lodging', 
    'rental', 'automotive', 'mechanic', 'pet', 'veterinary', 'storage', 'security', 'transportation',
    'delivery', 'logistics', 'utility', 'energy', 'sanitation', 'cleaning', 'waste', 'recycling',
]

include_pattern = re.compile(r'\b(?:' + '|'.join(food_keywords) + r')\b', re.IGNORECASE)
exclude_pattern = re.compile(r'\b(?:' + '|'.join(exclusions) + r')\b', re.IGNORECASE)

# %%
def is_food_service(category_list):
    """
    Check if any of the categories in the list match the food-related keywords
    and ensure none match the exclusions.
    """
    category_list = category_list if isinstance(category_list, list) else []
    if any(exclude_pattern.search(category) for category in category_list):
        return False
    return any(include_pattern.search(category) for category in category_list)

restaurant_metadata = [place for place in filtered_metadata if is_food_service(place.get('category'))]

# %%
df_restaurant_metadata = pd.DataFrame(restaurant_metadata)
df_restaurant_metadata.head()
# Out:
#                          name  \
# 0                San Soo Dang
# 1                Vons Chicken
# 2               Golden Castle
# 3             Oneyda's Bakery
# 4  Top Cat Seafood Restaurant
#
#                                              address  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2    Golden Castle, 1906 E 12th St, Austin, TX 78702
# 3  Oneyda's Bakery, 600 Goodlette-Frank Rd #101, ...
# 4  Top Cat Seafood Restaurant, 3117 Martin Luther...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42        None  33.916402 -118.010855
# 2  0x8644b59b8fe872e5:0x5e638876caa84cc3        None  30.273985  -97.719563
# 3  0x88dae191ee505917:0x6ba3e25388d3fad4        None  26.154754  -81.790528
# 4  0x864e9891e381f3df:0x4cefe6219bc9199c        None  32.773130  -96.764484
#
#                category  avg_rating  num_of_reviews price  \
# 0   [Korean restaurant]         4.4              18  None
# 1          [Restaurant]         4.5              18  None
# 2          [Restaurant]         4.5               8  None
# 3        [Bakery, Deli]         4.6              19     $
# 4  [Seafood restaurant]         3.9               8  None
#
#                                                hours  \
# 0  [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 1  [[Thursday, 11AM–9:30PM], [Friday, 11AM–9:30PM...
# 2  [[Thursday, 5PM–12AM], [Friday, 5PM–12AM], [Sa...
# 3  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 4  [[Thursday, 12–8PM], [Friday, 12–8PM], [Saturd...
#
#                                                 MISC       state  \
# 0  {'Service options': ['Takeout', 'Dine-in', 'De...  California
# 1  {'Service options': ['Outdoor seating', 'Curbs...  California
# 2  {'Service options': ['Delivery', 'Takeout', 'D...       Texas
# 3                  {'Service options': ['Delivery']}     Florida
# 4  {'Service options': ['Takeout', 'Dine-in', 'De...       Texas
#
#                                     relative_results  \
# 0  [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 1                                               None
# 2                                               None
# 3  [0x88dae1997e122d6b:0xfd776fa851f06d29, 0x88da...
# 4  [0x864e988def7880bf:0x981331c7ea3d01cd, 0x864e...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# **Check Categories**

# %%
exploded_categories = df_restaurant_metadata.explode('category')

category_counts = exploded_categories['category'].value_counts()

df_category_counts = category_counts.reset_index()
df_category_counts.columns = ['Category', 'Count']

df_category_counts.head()
# Out:
#              Category  Count
# 0          Restaurant   9331
# 1  Mexican restaurant   2913
# 2    Pizza restaurant   2080
# 3  Chinese restaurant   1949
# 4                Cafe   1646

# %% [markdown]
# ## Data Transformations
#
# This section outlines the transformation steps applied to clean and structure the restaurant metadata for analysis.
#
# ### Initial Cleanup
# - **Dropped Columns**: Columns such as `description`, `relative_results`, `MISC`, `hours`, and `url` were removed to focus on relevant data.
#
# ### Price Column Transformation
# - **Normalization**: Transformed `$` symbols in the `price` column to numeric values (`1`, `2`, `3`, `0` for missing) to represent price ranges.
#
# ### Geographic Data Extraction
# - **City and Postal Code**: Used regex to extract `city` and `postal_code` from the `address` column for detailed geographic analysis.
#
# ### Data Structuring
# - **Rearranging Columns**: Columns were reordered to improve data accessibility.
# - **Dummy Variables for Categories**: Expanded the `category` column into dummy variables for detailed category analysis.
# - **Creation of Dummy Tables**: Generated a separate table with `gmap_id` and category dummies for nuanced analysis.
#
# ### Data Integrity
# - **Duplicate Handling**: Identified and removed duplicates based on a composite key (`name`, `address`, `city`, `postal_code`).
# - **Missing Values**: Addressed missing values in essential columns, using default values or removal where necessary.
#
# ### Geolocation Correction
# - **Reverse Geocoding**: Populated missing `city` and `postal_code` fields using latitude and longitude data to enhance dataset accuracy.
#
# ### Final Adjustments
# - **Data Type Conversions**: Adjusted data types for specific columns like `postal_code` to ensure consistency across the dataset.
#
# By applying these transformations, the dataset is now primed for in-depth analysis, with a focus on maintaining integrity, usability, and analytical relevance.

# %% [markdown]
# **Initial Cleanup**

# %%
df_restaurant_clean = df_restaurant_metadata.drop(columns=['description', 'relative_results', 'MISC','hours','url'])

# %% [markdown]
# **Price Column Transformation**
# - 1 = Inexpensive, usually $10 and under
# - 2 = Moderately expensive, usually between $10 -$25
# - 3 = Expensive, usually between $25- $45
# - 4 = Very Expensive, usually $50 and up

# %%
def price_to_numeric(price):
    if pd.isnull(price):
        return None  
    else:
        return len(price)  

df_restaurant_clean['price_numeric'] = df_restaurant_clean['price'].apply(price_to_numeric)
df_restaurant_clean['price_numeric'] = df_restaurant_clean['price_numeric'].fillna("No Data")

# %%
def price_to_numeric(price):
    if pd.isnull(price):
        return 0  
    else:
        return len(price)  

df_restaurant_clean['price_numeric'] = df_restaurant_clean['price'].apply(price_to_numeric)
df_restaurant_clean.drop(columns=['price'], inplace=True)
df_restaurant_clean['price_numeric'] = df_restaurant_clean['price_numeric'].astype(int)

# %% [markdown]
# **Geographic Data Extraction**:
# - Data extrated from the adress column

# %%
city_regex = r',\s*([^,]+),\s*[A-Z]{2}\s+\d{5}'
postal_code_regex = r'(\d{5})$'

df_restaurant_clean['city'] = df_restaurant_clean['address'].str.extract(city_regex, expand=False)
df_restaurant_clean['postal_code'] = df_restaurant_clean['address'].str.extract(postal_code_regex, expand=False)

# %% [markdown]
# ### Data Structuring

# %% [markdown]
# **Rearranging Columns**

# %%
new_column_order = ['name', 'address','state', 'city', 'postal_code', 'latitude', 'longitude', 'avg_rating', 'num_of_reviews', 'price_numeric', 'gmap_id','category']
df_restaurant_clean = df_restaurant_clean.reindex(columns=new_column_order)

# %%
df_restaurant_clean.tail()
# Out:
#                            name  \
# 26909                    Luthun
# 26910            To Two Boonsik
# 26911                Matsunichi
# 26912        China King Express
# 26913  House of Gourmet -- 食全食美
#
#                                                  address     state       city  \
# 26909          Luthun, 432 E 13th St, New York, NY 10009  New York   New York
# 26910    To Two Boonsik, 97 Canal St, New York, NY 10002  New York   New York
# 26911  Matsunichi, 14-18 Elizabeth St #32-33, New Yor...  New York   New York
# 26912  China King Express, 6938 Erie Rd, Derby, NY 14047  New York      Derby
# 26913  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...  New York  Tonawanda
#
#       postal_code   latitude  longitude  avg_rating  num_of_reviews  \
# 26909       10009  40.729911 -73.981883         4.8              68
# 26910       10002  40.715612 -73.993828         4.3              45
# 26911       10013  40.715866 -73.997244         4.2              48
# 26912       14047  42.698185 -78.988253         4.1             118
# 26913       14150  42.980251 -78.827337         4.3              58
#
#        price_numeric                                gmap_id  \
# 26909              0  0x89c2592cf2935ed9:0x6672264426649f94
# 26910              0  0x89c25a286e6ea2db:0x1291d4bbf41d5ed4
# 26911              0  0x89c25a27a5c98845:0xad087746b0c3381a
# 26912              1  0x89d31f176b64da79:0x202faca0f650e880
# 26913              0   0x89d373386b718fff:0xf82c90ef48e7b23
#
#                                                 category
# 26909  [New American restaurant, American restaurant,...
# 26910                                [Korean restaurant]
# 26911                                 [Sushi restaurant]
# 26912                               [Chinese restaurant]
# 26913           [Chinese restaurant, Sichuan restaurant]

# %% [markdown]
# **Dummy Variables for Categories & Creation of Dummy Tables**

# %%
temp_df = df_restaurant_clean[['gmap_id', 'category']]
category_dummies = temp_df['category'].str.get_dummies(sep=', ')
restaurant_cat_dummies = pd.concat([temp_df[['gmap_id']], category_dummies], axis=1)
df_restaurant_clean = df_restaurant_clean.drop(columns=['category'])

# %%
df_restaurant_clean.head()
# Out:
#                          name  \
# 0                San Soo Dang
# 1                Vons Chicken
# 2               Golden Castle
# 3             Oneyda's Bakery
# 4  Top Cat Seafood Restaurant
#
#                                              address       state         city  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  California  Los Angeles
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...  California    La Mirada
# 2    Golden Castle, 1906 E 12th St, Austin, TX 78702       Texas       Austin
# 3  Oneyda's Bakery, 600 Goodlette-Frank Rd #101, ...     Florida       Naples
# 4  Top Cat Seafood Restaurant, 3117 Martin Luther...       Texas       Dallas
#
#   postal_code   latitude   longitude  avg_rating  num_of_reviews  \
# 0       90005  34.058092 -118.292130         4.4              18
# 1       90638  33.916402 -118.010855         4.5              18
# 2       78702  30.273985  -97.719563         4.5               8
# 3       34102  26.154754  -81.790528         4.6              19
# 4       75215  32.773130  -96.764484         3.9               8
#
#    price_numeric                                gmap_id
# 0              0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1              0  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 2              0  0x8644b59b8fe872e5:0x5e638876caa84cc3
# 3              1  0x88dae191ee505917:0x6ba3e25388d3fad4
# 4              0  0x864e9891e381f3df:0x4cefe6219bc9199c

# %%
restaurant_cat_dummies.tail()
# Out:
#                                      gmap_id  'Afghani restaurant'  \
# 26909  0x89c2592cf2935ed9:0x6672264426649f94                     0
# 26910  0x89c25a286e6ea2db:0x1291d4bbf41d5ed4                     0
# 26911  0x89c25a27a5c98845:0xad087746b0c3381a                     0
# 26912  0x89d31f176b64da79:0x202faca0f650e880                     0
# 26913   0x89d373386b718fff:0xf82c90ef48e7b23                     0
#
#        'African restaurant'  'African restaurant']  'American restaurant'  \
# 26909                     0                      0                      1
# 26910                     0                      0                      0
# 26911                     0                      0                      0
# 26912                     0                      0                      0
# 26913                     0                      0                      0
#
#        'American restaurant']  'Animal shelter']  'Argentinian restaurant'  \
# 26909                       0                  0                         0
# 26910                       0                  0                         0
# 26911                       0                  0                         0
# 26912                       0                  0                         0
# 26913                       0                  0                         0
#
#        'Armenian restaurant'  'Armenian restaurant']  ...  \
# 26909                      0                       0  ...
# 26910                      0                       0  ...
# 26911                      0                       0  ...
# 26912                      0                       0  ...
# 26913                      0                       0  ...
#
#        ['West African restaurant'  ['West African restaurant']  \
# 26909                           0                            0
# 26910                           0                            0
# 26911                           0                            0
# 26912                           0                            0
# 26913                           0                            0
#
#        ['Wholesale bakery'  ['Wholesale bakery']  ['Winery'  \
# 26909                    0                     0          0
# 26910                    0                     0          0
# 26911                    0                     0          0
# 26912                    0                     0          0
# 26913                    0                     0          0
#
#        ['Wok restaurant'  ['Wok restaurant']  ['Yakiniku restaurant'  \
# 26909                  0                   0                       0
# 26910                  0                   0                       0
# 26911                  0                   0                       0
# 26912                  0                   0                       0
# 26913                  0                   0                       0
#
#        ['Yakitori restaurant']  ['Yemenite restaurant']
# 26909                        0                        0
# 26910                        0                        0
# 26911                        0                        0
# 26912                        0                        0
# 26913                        0                        0
#
# [5 rows x 968 columns]

# %% [markdown]
# ### Data Integrity

# %% [markdown]
# **Duplicate Handling**:
# - important that the filtering has to be done based on a composite key since multiple restaurants exist with the same name but are in different locations

# %%
composite_key = ['name', 'address', 'city', 'postal_code']
duplicate_rows = df_restaurant_clean.duplicated(subset=composite_key, keep=False)

num_duplicate_rows = duplicate_rows.sum()
print(f"Number of rows with potential duplicates based on name, address, city, and postal code: {num_duplicate_rows}")

potential_duplicates = df_restaurant_clean[duplicate_rows]

sorted_potential_duplicates = potential_duplicates.sort_values(by='name')

print("Potential duplicate rows sorted by name:")
sorted_potential_duplicates.head()
# Out:
# Number of rows with potential duplicates based on name, address, city, and postal code: 412
# Potential duplicate rows sorted by name:
#                           name  \
# 63     'Round The Lake Kitchen
# 264    'Round The Lake Kitchen
# 96         1903 Taphouse & Co.
# 297        1903 Taphouse & Co.
# 14869           2 Korean Girls
#
#                                                  address         state  \
# 63     'Round The Lake Kitchen, 12057 PA-618, Conneau...  Pennsylvania
# 264    'Round The Lake Kitchen, 12057 PA-618, Conneau...  Pennsylvania
# 96     1903 Taphouse & Co., 175 N Main St, Bishop, CA...    California
# 297    1903 Taphouse & Co., 175 N Main St, Bishop, CA...    California
# 14869  2 Korean Girls, 2801a Florida Ave, Coconut Gro...       Florida
#
#                 city postal_code   latitude   longitude  avg_rating  \
# 63     Conneaut Lake       16316  41.630465  -80.325579         4.5
# 264    Conneaut Lake       16316  41.630465  -80.325579         4.5
# 96            Bishop       93514  37.361898 -118.395555         4.7
# 297           Bishop       93514  37.361898 -118.395555         4.7
# 14869  Coconut Grove       33133  25.729263  -80.240075         4.6
#
#        num_of_reviews  price_numeric                                gmap_id
# 63                 27              0  0x88324fdf1a955263:0x6b4077533d6e6061
# 264                27              0  0x88324fdf1a955263:0x6b4077533d6e6061
# 96                  8              0  0x80be3dd544115ed9:0x5d500f8046469ea3
# 297                 8              0  0x80be3dd544115ed9:0x5d500f8046469ea3
# 14869              45              0  0x88d9b76485f1a105:0x92bc2888314d41f4

# %%
df_restaurant_clean = df_restaurant_clean.drop_duplicates(subset=composite_key)

# %% [markdown]
# **Missing Values**
# - Checked for missing values
# - Manually checked those which had an empty `adress` all of these were clsoed etablishments and so we removed them from the data
# - For `posal code` and `city` reverse geocoding was used and explained further later

# %%
missing_values_count = df_restaurant_clean.isnull().sum()
print("Count of missing values in each column:")
print(missing_values_count)

# %%
rows_with_missing_values = df_restaurant_clean[df_restaurant_clean.isnull().any(axis=1)]
print("Rows with at least one missing value:")
rows_with_missing_values.head()
# Out:
# Rows with at least one missing value:
#                          name  \
# 36                      李小龍台吃
# 75                     glazed
# 928                 Me Bakery
# 942                Dada Sushi
# 1115  Juicy King Crab Express
#
#                                                 address       state city  \
# 36        〒11362 New York, Queens, Northern Blvd, 李小龍台吃    New York  NaN
# 75                 Texas, Sugar Land, glazed邮政编码: 77479       Texas  NaN
# 928   New York, Flushing, 47th Ave, Me Bakery邮政编码: 1...    New York  NaN
# 942   92562 California, Murrieta, California Oaks Rd...  California  NaN
# 1115  New York, Bronx, E Tremont Ave, Juicy King Cra...    New York  NaN
#
#      postal_code   latitude   longitude  avg_rating  num_of_reviews  \
# 36           NaN  40.770059  -73.735522         4.0              27
# 75         77479  29.590894  -95.625716         4.3               8
# 928        11358  40.752362  -73.785966         4.5              24
# 942          NaN  33.574236 -117.204089         4.2              34
# 1115       10457  40.845333  -73.890552         4.6             133
#
#       price_numeric                                gmap_id
# 36                0  0x89c289efdb82221b:0xed627c2af97c2069
# 75                0  0x8640e6bd6e861357:0xb96bb36e5cd02ee3
# 928               0  0x89c261a1df3470c3:0x1e414e9bf91c369f
# 942               0  0x80dc8385c954fc1f:0xa65cf0047f021902
# 1115              0  0x89c2f596580efdf1:0x1cec36682aa17eba

# %% [markdown]
# **Adress Empty:** Closed Establishemnts

# %%
rows_with_missing_address = df_restaurant_clean[df_restaurant_clean['address'].isnull()]
rows_with_missing_address.head()
# Out:
#                                                  name address       state  \
# 3229   Pasquale's Pizzeria and Restaurant at Wallkill    None    New York
# 3948                              Namaste Tashi Delek    None    New York
# 14070                            Sabaidee Thai Grille    None  California
# 14447                 Rios Mexican & Katracho Kitchen    None       Texas
# 14534                            Fox & Fawn Bakehouse    None  California
#
#        city postal_code   latitude   longitude  avg_rating  num_of_reviews  \
# 3229   None        None  41.710932  -74.112969         4.1              54
# 3948   None        None  40.759291  -73.884518         4.3              95
# 14070  None        None  37.275179 -119.273197         4.0              38
# 14447  None        None  29.319090  -94.978222         4.5              28
# 14534  None        None  38.109238 -122.125753         4.9              24
#
#        price_numeric                                gmap_id
# 3229               0  0x89dd29ab5dd170f1:0x7cb3c8e119a5bbe9
# 3948               0  0x89c25f072d742ce9:0x2a930399a15215e3
# 14070              0  0x809ac6a6aa8b8cdf:0xeb219547c732cc3c
# 14447              0  0x863f7fedb1f1dc55:0xe6f2db0b0f2d483f
# 14534              0  0x80856e3126db6b41:0x9412edbc6d853576

# %%
df_restaurant_clean = df_restaurant_clean.dropna(subset=['address'])

# %% [markdown]
# **Geolocation Correction**
# - Populated missing `postal_code` `city` coluumns with the use of Nominatim API
# - Multiple wrkers were used to speed up this process
#
# NOTE: Empty results after the functions were applied were converted to `No Data` and `00000` since the other information was deemed necesary and may be used for future examination despite these two missing values.

# %%
geolocator = Nominatim(user_agent='pef999@hotmail.com')
reverse_geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
def reverse_geocode_row(row, index):
    try:
        if pd.isnull(row['city']) or pd.isnull(row['postal_code']):
            location = reverse_geocode((row['latitude'], row['longitude']), exactly_one=True)
            address = location.raw.get('address', {})
            city = address.get('city', address.get('town', address.get('village')))
            postal_code = address.get('postcode')

            print(f"Row {index} updated: City = {city}, Postal Code = {postal_code}")
            return (index, city, postal_code)
    except Exception as e:
        print(f"Error retrieving location for row {index}: {e}")
    return (index, None, None)

# %%
def update_city_postal_code_parallel(df):
 
    results = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:  # Adjust max_workers as needed
        future_to_index = {executor.submit(reverse_geocode_row, row, index): index for index, row in df.iterrows()}
        for future in concurrent.futures.as_completed(future_to_index):
            index = future_to_index[future]
            try:
                result = future.result()
                results.append(result)
            except Exception as e:
                print(f"Error processing row {index}: {e}")
                
    for index, city, postal_code in results:
        if city:
            df.at[index, 'city'] = city
        if postal_code:
            df.at[index, 'postal_code'] = postal_code

    return df

# %%
df_restaurant_clean = update_city_postal_code_parallel(df_restaurant_clean)
# Out:
# Row 36 updated: City = City of New York, Postal Code = 11362
# Row 928 updated: City = City of New York, Postal Code = 11358
# Row 1985 updated: City = City of New York, Postal Code = 10003
# Row 942 updated: City = Murrieta, Postal Code = 92562
# Row 1408 updated: City = Philadelphia, Postal Code = 19111
# Row 1865 updated: City = Baldwin, Postal Code = 11510
# Row 75 updated: City = Sugar Land, Postal Code = 77479
# Row 1648 updated: City = None, Postal Code = 14738
# Row 2545 updated: City = City of New York, Postal Code = 11207
# Row 3650 updated: City = Middlesex Township, Postal Code = 17013
# Row 1444 updated: City = City of New York, Postal Code = 10451
# Row 2642 updated: City = Falls Township, Postal Code = 19030
# Row 3912 updated: City = Trappe, Postal Code = 19426
# Row 1115 updated: City = City of New York, Postal Code = 10457
# Row 3871 updated: City = City of New York, Postal Code = 11416
# Row 3704 updated: City = City of New York, Postal Code = 11361
# Row 2299 updated: City = Jericho, Postal Code = 11753
# Row 2756 updated: City = City of New York, Postal Code = 10019
# Row 3141 updated: City = Lower Merion Township, Postal Code = 19072
# Row 2190 updated: City = City of New York, Postal Code = 11226
# Row 6438 updated: City = Houston, Postal Code = 77008
# Row 5249 updated: City = None, Postal Code = 91745
# Row 6690 updated: City = City of New York, Postal Code = 11355
# Row 5183 updated: City = Susquehanna Township, Postal Code = 17103
# Row 7361 updated: City = City of New York, Postal Code = 11214
# Row 6373 updated: City = La Mirada, Postal Code = 90638
# Row 7413 updated: City = Diamond Bar, Postal Code = 91789
# Row 8906 updated: City = City of New York, Postal Code = 10019
# Row 7779 updated: City = None, Postal Code = 95827
# Row 9109 updated: City = City of New York, Postal Code = 10014
# Row 6891 updated: City = Los Angeles, Postal Code = 90064
# Row 1869 updated: City = Philadelphia, Postal Code = 19111
# Row 8899 updated: City = City of New York, Postal Code = 10019
# Row 7825 updated: City = City of New York, Postal Code = 11435
# Row 5210 updated: City = Santa Clarita, Postal Code = 91351
# Row 9529 updated: City = Azle, Postal Code = 76020
# Row 9716 updated: City = Corona, Postal Code = 92515
# Row 9083 updated: City = Town of Glenville, Postal Code = 12302
# Row 10797 updated: City = City of New York, Postal Code = 11354
# Row 9816 updated: City = Plainview, Postal Code = 79072
# Row 10709 updated: City = Town of Vestal, Postal Code = 13850
# Row 10827 updated: City = Village of Fishkill, Postal Code = 12524
# Row 9428 updated: City = Kendall, Postal Code = 33176
# Row 10328 updated: City = Port Saint Lucie, Postal Code = 34986
# Row 3504 updated: City = Lower Merion Township, Postal Code = 19003
# Row 7362 updated: City = None, Postal Code = None
# Row 9618 updated: City = Philadelphia, Postal Code = 19139
# Row 12092 updated: City = Dallas, Postal Code = 75254
# Row 13109 updated: City = Tarpon Springs, Postal Code = 34689
# Row 10748 updated: City = Lake Forest, Postal Code = 92630
# Row 13338 updated: City = City of New York, Postal Code = 11220
# Row 13311 updated: City = San Jose, Postal Code = 95129
# Row 7430 updated: City = Chambersburg, Postal Code = 17202
# Row 12548 updated: City = Houston, Postal Code = 77030
# Row 13523 updated: City = Norwalk, Postal Code = 90716
# Row 13350 updated: City = City of New York, Postal Code = 11204
# Row 11529 updated: City = Houston, Postal Code = 77060
# Row 11297 updated: City = Buena Park, Postal Code = 90621
# Row 14386 updated: City = None, Postal Code = None
# Row 11886 updated: City = City of New York, Postal Code = 11361
# Row 12349 updated: City = Orlando, Postal Code = 32835
# Row 14506 updated: City = City of New York, Postal Code = 11220
# Row 15110 updated: City = City of New York, Postal Code = 10453
# Row 14102 updated: City = Orlando, Postal Code = 32819
# Row 13942 updated: City = Village of Saugerties, Postal Code = 12477
# Row 14282 updated: City = Pomona, Postal Code = 91767
# Row 14141 updated: City = Monterey Park, Postal Code = 91754
# Row 12491 updated: City = Philadelphia, Postal Code = 19152
# Row 16252 updated: City = Mission, Postal Code = 78572
# Row 15219 updated: City = Glendale, Postal Code = 91214
# Row 16791 updated: City = Port Washington, Postal Code = 11050
# Row 16955 updated: City = Monterey Park, Postal Code = 91754
# Row 15815 updated: City = Gainesville, Postal Code = 32608
# Row 17303 updated: City = City of New York, Postal Code = 11355
# Row 17511 updated: City = Los Angeles, Postal Code = 90020
# Row 17548 updated: City = Winter Garden, Postal Code = 34787
# Row 15338 updated: City = City of New York, Postal Code = 11225
# Row 17624 updated: City = City of New York, Postal Code = 11220
# Row 17502 updated: City = San Diego, Postal Code = 92111
# Row 15905 updated: City = None, Postal Code = 91748
# Row 14561 updated: City = Huntington Beach, Postal Code = 92647
# Row 17071 updated: City = Los Angeles, Postal Code = 90057
# Row 17949 updated: City = Arlington, Postal Code = 76010
# Row 17878 updated: City = San Francisco, Postal Code = 94118
# Row 11030 updated: City = Orlovista, Postal Code = 32808
# Row 17967 updated: City = Mountain View, Postal Code = 94041
# Row 17953 updated: City = None, Postal Code = 77065
# Row 17968 updated: City = San Jose, Postal Code = 95123
# Row 17984 updated: City = Jacksonville, Postal Code = 32204
# Row 17926 updated: City = Jamestown, Postal Code = 14701
# Row 17996 updated: City = Town of Colonie, Postal Code = 12110
# Row 18001 updated: City = Los Gatos, Postal Code = 95030
# Row 18009 updated: City = Houston, Postal Code = 77057
# Row 18032 updated: City = Austin, Postal Code = 78748
# Row 17982 updated: City = Yardley, Postal Code = 19067
# Row 17951 updated: City = Houston, Postal Code = 77072
# Row 17950 updated: City = Houston, Postal Code = 77070
# Row 14177 updated: City = Edgmont Township, Postal Code = 19028
# Row 17966 updated: City = Los Gatos, Postal Code = 95032
# Row 18051 updated: City = Palmhurst, Postal Code = 78573
# Row 18073 updated: City = Bee Cave, Postal Code = 78738
# Row 18042 updated: City = None, Postal Code = 33186
# Row 17934 updated: City = None, Postal Code = 33428
# Row 18047 updated: City = Clermont, Postal Code = 32711
# Row 17989 updated: City = Richland Township, Postal Code = 15904
# Row 18096 updated: City = Farmers Branch, Postal Code = 75244
# Row 15438 updated: City = City of New York, Postal Code = 10003
# Row 18100 updated: City = San Antonio, Postal Code = 78240
# Row 18101 updated: City = San Antonio, Postal Code = 73232
# Row 18090 updated: City = Rosenberg, Postal Code = 77471
# Row 18098 updated: City = City of Yonkers, Postal Code = 10704
# Row 18110 updated: City = Lake City, Postal Code = 32055
# Row 18071 updated: City = Texarkana, Postal Code = 75503
# Row 18049 updated: City = Mission, Postal Code = 78572
# Row 18079 updated: City = West Hanover Township, Postal Code = 17112
# Row 18125 updated: City = City of New York, Postal Code = 10013
# Row 18089 updated: City = Wharton, Postal Code = 77488
# Row 18159 updated: City = Downey, Postal Code = 90241
# Row 18134 updated: City = San Francisco, Postal Code = 90103
# Row 18091 updated: City = Wharton, Postal Code = 77488
# Row 18173 updated: City = Buena Park, Postal Code = 90621
# Row 18175 updated: City = Saint Petersburg, Postal Code = 33702
# Row 18050 updated: City = Alton, Postal Code = 78572
# Row 18180 updated: City = City of New York, Postal Code = 10022
# Row 18181 updated: City = Conroe, Postal Code = 77304
# Row 18161 updated: City = Riverside, Postal Code = 92521
# Row 18136 updated: City = South San Francisco, Postal Code = 94080
# Row 18109 updated: City = Panama City Beach, Postal Code = 32408
# Row 18158 updated: City = La Habra, Postal Code = 90631
# Row 18205 updated: City = Longview, Postal Code = 75601
# Row 18195 updated: City = Benezette Township, Postal Code = 15821
# Row 18208 updated: City = Houston, Postal Code = 77074
# Row 18185 updated: City = San Juan Capistrano, Postal Code = 92675
# Row 18140 updated: City = Encinitas, Postal Code = 92024
# Row 18240 updated: City = Marfa, Postal Code = 79843
# Row 18186 updated: City = Tustin, Postal Code = 92780
# Row 18212 updated: City = Richmond, Postal Code = 94801
# Row 18183 updated: City = Laguna Beach, Postal Code = 92651
# Row 18274 updated: City = Salisbury, Postal Code = 11590
# Row 18179 updated: City = Carnegie, Postal Code = 15106
# Row 18273 updated: City = Palm Beach, Postal Code = 33480
# Row 18275 updated: City = City of New York, Postal Code = None
# Row 18135 updated: City = San Francisco, Postal Code = 94124
# Row 15047 updated: City = Berkeley, Postal Code = 94720
# Row 18284 updated: City = Aventura, Postal Code = 33180
# Row 18291 updated: City = Houston, Postal Code = 77040
# Row 18296 updated: City = Jacksonville, Postal Code = 32244
# Row 18294 updated: City = Jacksonville, Postal Code = 32222
# Row 18289 updated: City = Riviera Beach, Postal Code = 33404
# Row 18283 updated: City = City of New York, Postal Code = 10014
# Row 18277 updated: City = City of New York, Postal Code = 10014
# Row 18219 updated: City = Town of Patterson, Postal Code = 12563
# Row 18163 updated: City = Houston, Postal Code = 77007
# Row 18309 updated: City = San Francisco, Postal Code = 94112
# Row 18300 updated: City = Hayward, Postal Code = 94545
# Row 18326 updated: City = Los Angeles, Postal Code = 90071
# Row 18295 updated: City = Jacksonville, Postal Code = 32255
# Row 18328 updated: City = Los Angeles, Postal Code = 90026
# Row 18322 updated: City = Whittier, Postal Code = 90602
# Row 18331 updated: City = Los Angeles, Postal Code = 91401
# Row 18324 updated: City = Downey, Postal Code = 90242
# Row 18330 updated: City = La Habra, Postal Code = 90631
# Row 18334 updated: City = Santa Clarita, Postal Code = 91355
# Row 18325 updated: City = Lockhart, Postal Code = 78644
# Row 18297 updated: City = Jacksonville, Postal Code = 32244
# Row 18336 updated: City = Tustin, Postal Code = 92782
# Row 18344 updated: City = San Diego, Postal Code = 92126
# Row 18343 updated: City = San Diego, Postal Code = 92110
# Row 18332 updated: City = Los Angeles, Postal Code = 90029
# Row 18347 updated: City = Sacramento, Postal Code = 95835
# Row 18349 updated: City = Lauderhill, Postal Code = 33317
# Row 18249 updated: City = Irvine, Postal Code = 92618
# Row 18367 updated: City = Fountain Valley, Postal Code = 92708
# Row 18250 updated: City = San Simeon, Postal Code = 93452
# Row 18399 updated: City = San Francisco, Postal Code = 94104
# Row 18299 updated: City = East Palo Alto, Postal Code = 94301
# Row 18368 updated: City = Hemet, Postal Code = 92543
# Row 18346 updated: City = City of New York, Postal Code = 11220
# Row 18365 updated: City = Anaheim, Postal Code = 92801
# Row 18327 updated: City = Montebello, Postal Code = 90640
# Row 18412 updated: City = City of Albany, Postal Code = 12208
# Row 18416 updated: City = Clarence Center, Postal Code = 14032
# Row 18423 updated: City = Frisco, Postal Code = 75036
# Row 18410 updated: City = None, Postal Code = 90002
# Row 18429 updated: City = Brandon, Postal Code = 33511
# Row 18403 updated: City = Half Moon Bay, Postal Code = 94018
# Row 18333 updated: City = Santa Clarita, Postal Code = 91351
# Row 18337 updated: City = Irvine, Postal Code = 92618
# Row 18435 updated: City = Tampa, Postal Code = 33607
# Row 18298 updated: City = Union City, Postal Code = 94587
# Row 18438 updated: City = Clearwater, Postal Code = 33765
# Row 18402 updated: City = Emeryville, Postal Code = 94608
# Row 18430 updated: City = San Diego, Postal Code = 92123
# Row 18433 updated: City = Jasmine Estates, Postal Code = 34668
# Row 18432 updated: City = East Lake-Orient Park, Postal Code = 33610
# Row 18436 updated: City = South Bradenton, Postal Code = 34203
# Row 18452 updated: City = Oakland, Postal Code = 94606
# Row 18441 updated: City = Borger, Postal Code = 79007
# Row 18459 updated: City = Dallas, Postal Code = 75218
# Row 18440 updated: City = Winter Springs, Postal Code = 32708
# Row 18450 updated: City = San Francisco, Postal Code = 94122
# Row 18434 updated: City = Pinellas Park, Postal Code = 33781
# Row 18460 updated: City = Richardson, Postal Code = 75081
# Row 18524 updated: City = Pleasanton, Postal Code = 78064
# Row 18455 updated: City = Allen, Postal Code = 75013
# Row 18529 updated: City = Pembroke Pines, Postal Code = 33026
# Row 18477 updated: City = Town of Colonie, Postal Code = 12110
# Row 18418 updated: City = Coral Springs, Postal Code = 33065
# Row 18531 updated: City = Lakeland, Postal Code = 33802
# Row 18545 updated: City = San Bernardino, Postal Code = 92405
# Row 18442 updated: City = Saint Petersburg, Postal Code = 33702
# Row 18503 updated: City = Garden Grove, Postal Code = 92844
# Row 18548 updated: City = Village of Endicott, Postal Code = 13760
# Row 18544 updated: City = Rialto, Postal Code = 92376
# Row 18542 updated: City = Oceanside, Postal Code = 90257
# Row 18541 updated: City = San Bernardino, Postal Code = 92411
# Row 18523 updated: City = San Antonio, Postal Code = 78245
# Row 18569 updated: City = Burbank, Postal Code = 91504
# Row 18546 updated: City = Colton, Postal Code = 92324
# Row 18446 updated: City = Oldsmar, Postal Code = 34677
# Row 18584 updated: City = Lemoore, Postal Code = 93245
# Row 18561 updated: City = El Paso, Postal Code = 79907
# Row 18415 updated: City = Town of Amherst, Postal Code = 14051
# Row 18573 updated: City = Vidor, Postal Code = 77662
# Row 18594 updated: City = Richardson, Postal Code = 75081
# Row 18345 updated: City = San Diego, Postal Code = 92128
# Row 18562 updated: City = West Odessa, Postal Code = 79763
# Row 18547 updated: City = Rialto, Postal Code = 92376
# Row 18588 updated: City = Saint Cloud, Postal Code = 34769
# Row 18600 updated: City = City of New York, Postal Code = 11372
# Row 18599 updated: City = Manhasset, Postal Code = 11030
# Row 18598 updated: City = Village of Westbury, Postal Code = 11590
# Row 18581 updated: City = City of New York, Postal Code = 11372
# Row 18601 updated: City = City of New York, Postal Code = 11354
# Row 18595 updated: City = Houston, Postal Code = 77036
# Row 18563 updated: City = El Paso, Postal Code = 79907
# Row 18644 updated: City = Los Angeles, Postal Code = 90031
# Row 18590 updated: City = Martinez, Postal Code = 94553
# Row 18582 updated: City = Hicksville, Postal Code = 11801
# Row 18642 updated: City = Miami, Postal Code = 33133
# Row 18656 updated: City = Buena Park, Postal Code = 90621
# Row 18653 updated: City = City of New York, Postal Code = 10001
# Row 18658 updated: City = Huntington Beach, Postal Code = 92647
# Row 18664 updated: City = Village of Brockport, Postal Code = 14420
# Row 18652 updated: City = City of New York, Postal Code = 10002
# Row 18670 updated: City = Stockton, Postal Code = 95206
# Row 18673 updated: City = Los Angeles, Postal Code = 91601
# Row 18677 updated: City = City of New York, Postal Code = 11104
# Row 18671 updated: City = Pasadena, Postal Code = 77502
# Row 18637 updated: City = Palm Springs, Postal Code = 99262
# Row 18710 updated: City = Santa Maria, Postal Code = 93454
# Row 18711 updated: City = Santa Maria, Postal Code = 93548
# Row 18706 updated: City = Santa Maria, Postal Code = 93548
# Row 18713 updated: City = Arroyo Grande, Postal Code = 93445
# Row 18625 updated: City = Houston, Postal Code = 77093
# Row 18638 updated: City = Indio, Postal Code = 92201
# Row 18705 updated: City = Santa Maria, Postal Code = 93548
# Row 18715 updated: City = City of Utica, Postal Code = 13502
# Row 18717 updated: City = Melbourne, Postal Code = 32935
# Row 18749 updated: City = San Antonio, Postal Code = 78245
# Row 18753 updated: City = Paso Robles, Postal Code = 93446
# Row 18718 updated: City = Melbourne, Postal Code = 32901
# Row 18766 updated: City = Los Angeles, Postal Code = 90029
# Row 18752 updated: City = Town of Islip, Postal Code = 11739
# Row 18672 updated: City = Los Angeles, Postal Code = 90291
# Row 18712 updated: City = Santa Maria, Postal Code = 93455
# Row 18790 updated: City = El Paso, Postal Code = 79938
# Row 18754 updated: City = Paso Robles, Postal Code = 93446
# Row 18591 updated: City = Houston, Postal Code = 77058
# Row 18602 updated: City = Village of New Hyde Park, Postal Code = 11040
# Row 18797 updated: City = Deer Park, Postal Code = 77536
# Row 18807 updated: City = Rialto, Postal Code = 92376
# Row 18657 updated: City = Diamond Bar, Postal Code = 91765
# Row 18767 updated: City = Fort Worth, Postal Code = 76164
# Row 18812 updated: City = San Carlos, Postal Code = 94064
# Row 18821 updated: City = Garden Grove, Postal Code = 92844
# Row 18620 updated: City = Scranton, Postal Code = 18509
# Row 18808 updated: City = East Meadow, Postal Code = 11554
# Row 18826 updated: City = Huntington Beach, Postal Code = 92648
# Row 18809 updated: City = East Meadow, Postal Code = 11554
# Row 18820 updated: City = Garden Grove, Postal Code = 92843
# Row 18822 updated: City = Austin, Postal Code = 78753
# Row 18832 updated: City = Irvine, Postal Code = 92602
# Row 18852 updated: City = Los Angeles, Postal Code = 90004
# Row 18798 updated: City = None, Postal Code = 14469
# Row 18854 updated: City = Los Angeles, Postal Code = 90501
# Row 18716 updated: City = City of New York, Postal Code = 11215
# Row 18828 updated: City = Artesia, Postal Code = 90701
# Row 18829 updated: City = Garden Grove, Postal Code = 92843
# Row 18768 updated: City = Daytona Beach, Postal Code = 32118
# Row 18858 updated: City = City of New York, Postal Code = 10035
# Row 18810 updated: City = San Bruno, Postal Code = 94066
# Row 18883 updated: City = Sanger, Postal Code = None
# Row 18874 updated: City = Torrance, Postal Code = 90503
# Row 18780 updated: City = None, Postal Code = 92061
# Row 18906 updated: City = Palmetto, Postal Code = 34221
# Row 18917 updated: City = Corpus Christi, Postal Code = 78412
# Row 18875 updated: City = Los Angeles, Postal Code = 90247
# Row 18926 updated: City = Town of Milford, Postal Code = 13807
# Row 18878 updated: City = Elk Grove, Postal Code = 95624
# Row 18851 updated: City = Ojai, Postal Code = 93023
# Row 18853 updated: City = Los Angeles, Postal Code = 90048
# Row 18900 updated: City = Philadelphia, Postal Code = 19114
# Row 18830 updated: City = Huntington Beach, Postal Code = 92649
# Row 18864 updated: City = Fort Worth, Postal Code = 76179
# Row 18960 updated: City = Orlando, Postal Code = 32835
# Row 18942 updated: City = Kenneth City, Postal Code = 33709
# Row 18934 updated: City = Austin, Postal Code = 78702
# Row 18962 updated: City = Lynn Haven, Postal Code = 32444
# Row 18959 updated: City = Hialeah Gardens, Postal Code = 33016
# Row 18968 updated: City = Town of Colonie, Postal Code = 12110
# Row 18961 updated: City = None, Postal Code = 32814
# Row 18921 updated: City = None, Postal Code = 16371
# Row 19004 updated: City = Weatherford, Postal Code = 76086
# Row 18991 updated: City = New Smyrna Beach, Postal Code = 32168
# Row 18881 updated: City = Sacramento, Postal Code = 95823
# Row 18957 updated: City = Sacramento, Postal Code = 95833
# Row 19009 updated: City = Santa Rosa, Postal Code = 95404
# Row 19025 updated: City = Sugar Land, Postal Code = 77479
# Row 19002 updated: City = Vista, Postal Code = 92084
# Row 19015 updated: City = Buena Park, Postal Code = 90620
# Row 18943 updated: City = Pembroke Pines, Postal Code = 33024
# Row 18967 updated: City = Town of Ancram, Postal Code = 12502
# Row 19047 updated: City = El Paso, Postal Code = 79925
# Row 19041 updated: City = None, Postal Code = 77373
# Row 18885 updated: City = Fresno, Postal Code = 93727
# Row 19010 updated: City = Fort Bragg, Postal Code = 95437
# Row 19072 updated: City = Irvine, Postal Code = 92606
# Row 19093 updated: City = Fairfield, Postal Code = 94533
# Row 19101 updated: City = Cameron, Postal Code = 76520
# Row 19036 updated: City = Lewisville, Postal Code = 75067
# Row 18945 updated: City = Largo, Postal Code = 33771
# Row 19106 updated: City = Compton, Postal Code = 90221
# Row 19008 updated: City = Fort Bragg, Postal Code = 95437
# Row 19044 updated: City = Palo Alto, Postal Code = 94301
# Row 19158 updated: City = None, Postal Code = 79735
# Row 19045 updated: City = Millbrae, Postal Code = 94030
# Row 19166 updated: City = Los Angeles, Postal Code = 91401
# Row 19107 updated: City = Norwalk, Postal Code = 90638
# Row 19006 updated: City = Dickinson, Postal Code = 77539
# Row 19128 updated: City = Cypress, Postal Code = 90630
# Row 19202 updated: City = None, Postal Code = 32547
# Row 19193 updated: City = Angels Camp, Postal Code = 95222
# Row 19065 updated: City = San Fernando, Postal Code = 91340
# Row 19162 updated: City = City of New York, Postal Code = 11373
# Row 19064 updated: City = Los Angeles, Postal Code = 91312
# Row 19141 updated: City = None, Postal Code = 77067
# Row 19070 updated: City = Newport Beach, Postal Code = 92660
# Row 19184 updated: City = San Antonio, Postal Code = 78204
# Row 19234 updated: City = Buffalo, Postal Code = 14214
# Row 19228 updated: City = City of Ogdensburg, Postal Code = 13669
# Row 19183 updated: City = San Antonio, Postal Code = 78232
# Row 19223 updated: City = Town of Coxsackie, Postal Code = 12051
# Row 19229 updated: City = None, Postal Code = 13654
# Row 19226 updated: City = Escondido, Postal Code = 92027
# Row 19245 updated: City = Yucaipa, Postal Code = 92399
# Row 19109 updated: City = Long Beach, Postal Code = 90805
# Row 19272 updated: City = City of New York, Postal Code = 11379
# Row 19250 updated: City = Jacksonville, Postal Code = 32224
# Row 19225 updated: City = Escondido, Postal Code = 92027
# Row 19267 updated: City = None, Postal Code = 77494
# Row 19259 updated: City = Village of Suffern, Postal Code = 10901
# Row 19292 updated: City = Lompoc, Postal Code = 93436
# Row 19210 updated: City = Paramount, Postal Code = 90723
# Row 19235 updated: City = Buffalo, Postal Code = 14215
# Row 19258 updated: City = Nanuet, Postal Code = 10954
# Row 19305 updated: City = None, Postal Code = 77070
# Row 19290 updated: City = Orcutt, Postal Code = 93455
# Row 19313 updated: City = Houston, Postal Code = 77025
# Row 19281 updated: City = Sunny Isles Beach, Postal Code = 33160
# Row 19312 updated: City = Orlando, Postal Code = 32807
# Row 19325 updated: City = Bell, Postal Code = 90201
# Row 19274 updated: City = El Paso, Postal Code = 79936
# Row 19301 updated: City = Town of Palmyra, Postal Code = 14522
# Row 19302 updated: City = City of Rochester, Postal Code = 14606
# Row 19372 updated: City = Arlington, Postal Code = 76011
# Row 19355 updated: City = Dallas, Postal Code = 75217
# Row 19211 updated: City = Orange, Postal Code = 92866
# Row 19327 updated: City = Costa Mesa, Postal Code = 92626
# Row 19366 updated: City = Fort Worth, Postal Code = 76106
# Row 19392 updated: City = Berkeley, Postal Code = 94705
# Row 19369 updated: City = Arlington, Postal Code = 76015
# Row 19342 updated: City = Santa Rosa, Postal Code = 95405
# Row 19373 updated: City = Fort Lauderdale, Postal Code = 33315
# Row 19422 updated: City = Pharr, Postal Code = 78577
# Row 19387 updated: City = San Francisco, Postal Code = 94104
# Row 19314 updated: City = None, Postal Code = 77386
# Row 19428 updated: City = City of White Plains, Postal Code = 10601
# Row 19431 updated: City = City of Yonkers, Postal Code = 10701
# Row 19409 updated: City = None, Postal Code = 32828
# Row 19423 updated: City = Odessa, Postal Code = 79762
# Row 19454 updated: City = South Bradenton, Postal Code = 34208
# Row 19284 updated: City = Los Angeles, Postal Code = 91316
# Row 19467 updated: City = Lubbock, Postal Code = 79414
# Row 19468 updated: City = Lubbock, Postal Code = 79414
# Row 19449 updated: City = Lansdale, Postal Code = 19446
# Row 19476 updated: City = Huntington Beach, Postal Code = 92647
# Row 19456 updated: City = Coronado, Postal Code = 92118
# Row 19443 updated: City = McAllen, Postal Code = 78501
# Row 19487 updated: City = Fountain Valley, Postal Code = 92708
# Row 19474 updated: City = Los Angeles, Postal Code = 90045
# Row 19492 updated: City = Miami Springs, Postal Code = 33166
# Row 19440 updated: City = None, Postal Code = 32548
# Row 19442 updated: City = Mission, Postal Code = 78572
# Row 19375 updated: City = San Diego, Postal Code = 92128
# Row 19427 updated: City = City of Yonkers, Postal Code = 10701
# Row 19358 updated: City = Los Angeles, Postal Code = 90057
# Row 19533 updated: City = Houston, Postal Code = 77072
# Row 19516 updated: City = El Paso, Postal Code = 79936
# Row 19535 updated: City = Katy, Postal Code = 77449
# Row 19378 updated: City = Sanger, Postal Code = 93616
# Row 19521 updated: City = City of Rochester, Postal Code = 14620
# Row 19564 updated: City = San Antonio, Postal Code = 78227
# Row 19507 updated: City = City of New York, Postal Code = 11354
# Row 19552 updated: City = Brentwood, Postal Code = 94513
# Row 19517 updated: City = El Paso, Postal Code = 79901
# Row 19477 updated: City = Huntington Beach, Postal Code = 92648
# Row 19538 updated: City = Fort Worth, Postal Code = 76132
# Row 19570 updated: City = Stockton, Postal Code = 95205
# Row 19569 updated: City = Stockton, Postal Code = 95204
# Row 19592 updated: City = Susanville, Postal Code = 96130
# Row 19577 updated: City = Modesto, Postal Code = 95356
# Row 19574 updated: City = Stockton, Postal Code = 95202
# Row 19601 updated: City = Dallas, Postal Code = 75241
# Row 19602 updated: City = Midland, Postal Code = 79707
# Row 19603 updated: City = Dallas, Postal Code = 75211
# Row 19598 updated: City = Odessa, Postal Code = 79762
# Row 19490 updated: City = Addison, Postal Code = 75001
# Row 19573 updated: City = Stockton, Postal Code = 95207
# Row 19479 updated: City = Tustin, Postal Code = 92780
# Row 19607 updated: City = Odessa, Postal Code = 79762
# Row 19612 updated: City = Midland, Postal Code = 79707
# Row 19582 updated: City = Palm Coast, Postal Code = 32137
# Row 19605 updated: City = Rockwall, Postal Code = 75087
# Row 19604 updated: City = Dallas, Postal Code = 75134
# Row 19638 updated: City = South Strabane Township, Postal Code = 15301
# Row 19640 updated: City = None, Postal Code = 34208
# Row 19637 updated: City = South Strabane Township, Postal Code = 15301
# Row 19648 updated: City = San Diego, Postal Code = 92102
# Row 19618 updated: City = Santa Rosa, Postal Code = 95402
# Row 19649 updated: City = San Diego, Postal Code = 92128
# Row 19635 updated: City = Katy, Postal Code = 77494
# Row 19660 updated: City = San Francisco, Postal Code = 90103
# Row 19610 updated: City = Midland, Postal Code = 79707
# Row 19665 updated: City = San Francisco, Postal Code = 94133
# Row 19669 updated: City = Miami Beach, Postal Code = 33139
# Row 19654 updated: City = Manteca, Postal Code = 95336
# Row 19593 updated: City = Odessa, Postal Code = 79762
# Row 19644 updated: City = Friendswood, Postal Code = 77546
# Row 19677 updated: City = McAllen, Postal Code = 78504
# Row 19697 updated: City = Riverview, Postal Code = 33578
# Row 19686 updated: City = Sanford, Postal Code = 32773
# Row 19647 updated: City = National City, Postal Code = 91950
# Row 19667 updated: City = Houston, Postal Code = 77060
# Row 19680 updated: City = Edinburg, Postal Code = 78539
# Row 19715 updated: City = Solebury Township, Postal Code = 18938
# Row 19534 updated: City = Houston, Postal Code = 77079
# Row 19499 updated: City = Town of Camillus, Postal Code = 13031
# Row 19726 updated: City = None, Postal Code = 77449
# Row 19721 updated: City = City of New York, Postal Code = 11693
# Row 19676 updated: City = McAllen, Postal Code = 78504
# Row 19729 updated: City = Village/Town of Mount Kisco, Postal Code = 10549
# Row 19720 updated: City = City of New York, Postal Code = 11417
# Row 19747 updated: City = None, Postal Code = 34201
# Row 19757 updated: City = Stanton, Postal Code = 90680
# Row 19758 updated: City = Redondo Beach, Postal Code = 90277
# Row 19700 updated: City = Town of Monroe, Postal Code = 10926
# Row 19594 updated: City = Odessa, Postal Code = 79762
# Row 19760 updated: City = Lake Forest, Postal Code = 92630
# Row 19712 updated: City = Sabinal, Postal Code = 78881
# Row 19743 updated: City = Pittsburgh, Postal Code = 15205
# Row 19716 updated: City = City of New York, Postal Code = 11104
# Row 19666 updated: City = San Francisco, Postal Code = 94109
# Row 19807 updated: City = Town of Mount Pleasant, Postal Code = 10532
# Row 19752 updated: City = Humble, Postal Code = 77396
# Row 19759 updated: City = Redondo Beach, Postal Code = 90277
# Row 19809 updated: City = New Braunfels, Postal Code = 78130
# Row 19806 updated: City = Village of Irvington, Postal Code = 10533
# Row 19779 updated: City = Houston, Postal Code = 77083
# Row 19819 updated: City = Amarillo, Postal Code = 79109
# Row 19808 updated: City = North Richland Hills, Postal Code = 76180
# Row 19840 updated: City = La Mirada, Postal Code = 90638
# Row 19852 updated: City = Miami Shores, Postal Code = 33138
# Row 19839 updated: City = Moreno Valley, Postal Code = 92553
# Row 19853 updated: City = Katy, Postal Code = 77449
# Row 19855 updated: City = Houston, Postal Code = 77002
# Row 19746 updated: City = Austin, Postal Code = 78767
# Row 19848 updated: City = Chino, Postal Code = 91710
# Row 19847 updated: City = Chino, Postal Code = 91710
# Row 19713 updated: City = Uvalde, Postal Code = 78801
# Row 19868 updated: City = Okeechobee, Postal Code = 34974
# Row 19881 updated: City = Fort Worth, Postal Code = 76109
# Row 19841 updated: City = La Mirada, Postal Code = 90639
# Row 19872 updated: City = San Diego, Postal Code = 92163
# Row 19889 updated: City = Miami, Postal Code = 33142
# Row 19851 updated: City = Houston, Postal Code = 77002
# Row 19882 updated: City = Tallahassee, Postal Code = 32301
# Row 19906 updated: City = San Jose, Postal Code = 95121
# Row 19907 updated: City = Milpitas, Postal Code = 95035
# Row 19862 updated: City = Philadelphia, Postal Code = 19107
# Row 19909 updated: City = Cupertino, Postal Code = 95014
# Row 19854 updated: City = Houston, Postal Code = 77077
# Row 19911 updated: City = New Braunfels, Postal Code = 78130
# Row 19918 updated: City = City of New York, Postal Code = 11354
# Row 19783 updated: City = Hermitage, Postal Code = 16148
# Row 19905 updated: City = Alvin, Postal Code = 77511
# Row 19946 updated: City = Malvern, Postal Code = 19355
# Row 19892 updated: City = Homestead, Postal Code = 33030
# Row 19960 updated: City = Arlington, Postal Code = 76015
# Row 19900 updated: City = City of New York, Postal Code = 10003
# Row 19871 updated: City = Middletown Township, Postal Code = 19056
# Row 19952 updated: City = San Bernardino, Postal Code = 92405
# Row 19908 updated: City = Key West, Postal Code = 33041
# Row 19991 updated: City = Los Angeles, Postal Code = 90005
# Row 19986 updated: City = Alameda, Postal Code = 94501
# Row 19987 updated: City = Philadelphia, Postal Code = 19107
# Row 20015 updated: City = Tampa, Postal Code = 33617
# Row 19974 updated: City = Vista, Postal Code = 92081
# Row 19910 updated: City = Cuero, Postal Code = 77954
# Row 20055 updated: City = Tomball, Postal Code = 77375
# Row 19947 updated: City = Lower Providence Township, Postal Code = 19403
# Row 20034 updated: City = City of New York, Postal Code = 11368
# Row 20001 updated: City = Cleburne, Postal Code = 76033
# Row 20063 updated: City = Clearlake, Postal Code = 95422
# Row 20074 updated: City = San Antonio, Postal Code = 78218
# Row 20078 updated: City = Philadelphia, Postal Code = 19148
# Row 20057 updated: City = Willis, Postal Code = 77378
# Row 20064 updated: City = None, Postal Code = 95457
# Row 19965 updated: City = Bishop, Postal Code = None
# Row 20056 updated: City = Old Town Spring, Postal Code = 77388
# Row 20079 updated: City = Philadelphia, Postal Code = 19142
# Row 19890 updated: City = Miami Gardens, Postal Code = 33169
# Row 20099 updated: City = Middletown Township, Postal Code = 19047
# Row 20032 updated: City = City of New York, Postal Code = 10003
# Row 20042 updated: City = Los Angeles, Postal Code = 90004
# Row 20098 updated: City = Pocono Township, Postal Code = 18372
# Row 20101 updated: City = Penndel, Postal Code = 19047
# Row 20105 updated: City = Houston, Postal Code = 77063
# Row 20108 updated: City = Philadelphia, Postal Code = 19151
# Row 20084 updated: City = Los Angeles, Postal Code = 91605
# Row 20083 updated: City = Los Angeles, Postal Code = 91364
# Row 20115 updated: City = McKinney, Postal Code = 75069
# Row 20106 updated: City = Houston, Postal Code = 77077
# Row 20114 updated: City = Frisco, Postal Code = 75034
# Row 20116 updated: City = None, Postal Code = 34201
# Row 20120 updated: City = City of Ithaca, Postal Code = 14851
# Row 20137 updated: City = Austin, Postal Code = 78745
# Row 20119 updated: City = North Manheim Township, Postal Code = 17972
# Row 19970 updated: City = Los Angeles, Postal Code = 91604
# Row 20141 updated: City = Abilene, Postal Code = 79605
# Row 20146 updated: City = Anna Maria island, Postal Code = 34216
# Row 20131 updated: City = Austin, Postal Code = 78704
# Row 20174 updated: City = Los Angeles, Postal Code = 91316
# Row 20107 updated: City = None, Postal Code = 77450
# Row 20135 updated: City = Austin, Postal Code = 78745
# Row 20145 updated: City = Lakeway, Postal Code = 78738
# Row 20182 updated: City = Killeen, Postal Code = 76541
# Row 20193 updated: City = Vacaville, Postal Code = 95687
# Row 19822 updated: City = Venice, Postal Code = 34285
# Row 20175 updated: City = Santa Monica, Postal Code = 90404
# Row 20163 updated: City = City of New York, Postal Code = 11238
# Row 20216 updated: City = Midlothian, Postal Code = 76065
# Row 20211 updated: City = City of New York, Postal Code = 11421
# Row 20104 updated: City = Philadelphia, Postal Code = 19129
# Row 20218 updated: City = Midlothian, Postal Code = 76065
# Row 20112 updated: City = Miami, Postal Code = 33135
# Row 20225 updated: City = Pembroke Pines, Postal Code = 33027
# Row 20142 updated: City = Mountain View, Postal Code = 94043
# Row 20130 updated: City = Carrollton, Postal Code = 75007
# Row 20181 updated: City = Chino, Postal Code = 91709
# Row 20183 updated: City = Harker Heights, Postal Code = 76548
# Row 20236 updated: City = Clovis, Postal Code = 03619
# Row 20257 updated: City = San Francisco, Postal Code = 94110
# Row 20254 updated: City = Los Angeles, Postal Code = 90047
# Row 20246 updated: City = San Jose, Postal Code = 95111
# Row 20275 updated: City = Lauderdale Lakes, Postal Code = 33319
# Row 20276 updated: City = Plantation, Postal Code = 33324
# Row 20274 updated: City = Tallahassee, Postal Code = 32303
# Row 20256 updated: City = Oakland, Postal Code = 94606
# Row 20244 updated: City = Cupertino, Postal Code = 95014
# Row 20281 updated: City = San Luis Obispo, Postal Code = 93405
# Row 20280 updated: City = West Covina, Postal Code = 91790
# Row 20279 updated: City = Ontario, Postal Code = 91743
# Row 20220 updated: City = Naples, Postal Code = 34102
# Row 20282 updated: City = South El Monte, Postal Code = 91733
# Row 20241 updated: City = City of New York, Postal Code = 11210
# Row 20283 updated: City = La Puente, Postal Code = 91744
# Row 20231 updated: City = Fort Worth, Postal Code = 76036
# Row 20290 updated: City = Los Angeles, Postal Code = 90005
# Row 20286 updated: City = Los Angeles, Postal Code = 90008
# Row 20215 updated: City = Plano, Postal Code = 75024
# Row 20293 updated: City = Los Angeles, Postal Code = 90293
# Row 20295 updated: City = Burbank, Postal Code = 91504
# Row 20285 updated: City = Hawthorne, Postal Code = 90250
# Row 20291 updated: City = Los Angeles, Postal Code = 91608
# Row 20304 updated: City = Lawndale, Postal Code = 90260
# Row 20294 updated: City = Carson, Postal Code = 90503
# Row 20306 updated: City = Gardena, Postal Code = 90247
# Row 20297 updated: City = City of New York, Postal Code = 10021
# Row 20308 updated: City = Compton, Postal Code = 90221
# Row 20310 updated: City = Lynwood, Postal Code = 90262
# Row 20262 updated: City = Sacramento, Postal Code = 95835
# Row 20313 updated: City = Topanga, Postal Code = None
# Row 20307 updated: City = Lakewood, Postal Code = 90712
# Row 20314 updated: City = Santa Clarita, Postal Code = 91355
# Row 20311 updated: City = Inglewood, Postal Code = 90304
# Row 20328 updated: City = Sunset Valley, Postal Code = 78715
# Row 20287 updated: City = Los Angeles, Postal Code = 91340
# Row 20363 updated: City = Bedford Township, Postal Code = 15522
# Row 20367 updated: City = Fullerton, Postal Code = 90631
# Row 20240 updated: City = City of New York, Postal Code = 11203
# Row 20321 updated: City = San Antonio, Postal Code = 78216
# Row 20349 updated: City = City of Olean, Postal Code = 14760
# Row 20288 updated: City = Los Angeles, Postal Code = 90710
# Row 20292 updated: City = Los Angeles, Postal Code = 90042
# Row 20289 updated: City = Torrance, Postal Code = 90504
# Row 20369 updated: City = Buena Park, Postal Code = 90621
# Row 20340 updated: City = Berkeley, Postal Code = 94707
# Row 20383 updated: City = West Park, Postal Code = 33023
# Row 20382 updated: City = Vero Beach, Postal Code = 32960
# Row 20386 updated: City = Camarillo, Postal Code = 93010
# Row 20395 updated: City = Pine Island, Postal Code = 33324
# Row 20402 updated: City = Long Beach, Postal Code = 90846
# Row 20403 updated: City = Long Beach, Postal Code = 90807
# Row 20417 updated: City = Neptune Beach, Postal Code = 32266
# Row 20401 updated: City = Compton, Postal Code = 90059
# Row 20393 updated: City = None, Postal Code = 33311
# Row 20426 updated: City = Bryan, Postal Code = 77803
# Row 20296 updated: City = City of New York, Postal Code = 10013
# Row 20431 updated: City = Miami Beach, Postal Code = 33139
# Row 20437 updated: City = Los Angeles, Postal Code = 90042
# Row 20390 updated: City = Plantation, Postal Code = 33322
# Row 20420 updated: City = Selma, Postal Code = 78148
# Row 20405 updated: City = Whittier, Postal Code = 90602
# Row 20443 updated: City = Santa Ana, Postal Code = 92701
# Row 20422 updated: City = Lake Katrine, Postal Code = 12449
# Row 20380 updated: City = Port Saint Lucie, Postal Code = 34986
# Row 20432 updated: City = Los Angeles, Postal Code = 90032
# Row 20370 updated: City = Cerritos, Postal Code = 90703
# Row 20309 updated: City = Long Beach, Postal Code = 90805
# Row 20493 updated: City = Naples, Postal Code = 34102
# Row 20460 updated: City = City of New York, Postal Code = 11419
# Row 20494 updated: City = Brownsville, Postal Code = 78521
# Row 20456 updated: City = Corpus Christi, Postal Code = 78413
# Row 20536 updated: City = None, Postal Code = 33598
# Row 20566 updated: City = None, Postal Code = 33912
# Row 20542 updated: City = Lakewood, Postal Code = 90716
# Row 20491 updated: City = Tallahassee, Postal Code = 32303
# Row 20539 updated: City = Cypress, Postal Code = 90630
# Row 20543 updated: City = Temple City, Postal Code = 91780
# Row 20583 updated: City = Houston, Postal Code = 77080
# Row 20589 updated: City = Town/Village of East Rochester, Postal Code = 14625
# Row 20584 updated: City = Tomball, Postal Code = 77375
# Row 20585 updated: City = Tomball, Postal Code = 77375
# Row 20595 updated: City = City of New York, Postal Code = 11217
# Row 20520 updated: City = Altamonte Springs, Postal Code = 32714
# Row 20604 updated: City = Rancho Cucamonga, Postal Code = 91730
# Row 20586 updated: City = Town/Village of East Rochester, Postal Code = 14625
# Row 20534 updated: City = Merritt Island, Postal Code = 32952
# Row 20610 updated: City = Seagoville, Postal Code = 75159
# Row 20614 updated: City = Shenandoah, Postal Code = 77385
# Row 20596 updated: City = City of New York, Postal Code = 10011
# Row 20608 updated: City = Balch Springs, Postal Code = 75180
# Row 20590 updated: City = City of Niagara Falls, Postal Code = 14301
# Row 20618 updated: City = Morgan Hill, Postal Code = 95038
# Row 20622 updated: City = Bullard, Postal Code = 75757
# Row 20525 updated: City = Pembroke Park, Postal Code = 33023
# Row 20368 updated: City = Buena Park, Postal Code = 90621
# Row 20655 updated: City = City of New York, Postal Code = 11422
# Row 20612 updated: City = Dallas, Postal Code = 75217
# Row 20665 updated: City = Fort Worth, Postal Code = 76177
# Row 20664 updated: City = Wyomissing, Postal Code = 19610
# Row 20645 updated: City = Forest Hill, Postal Code = 76140
# Row 20594 updated: City = Alameda, Postal Code = 94501
# Row 20616 updated: City = Amarillo, Postal Code = 79109
# Row 20615 updated: City = Amarillo, Postal Code = 79106
# Row 20683 updated: City = San Antonio, Postal Code = 78230
# Row 20577 updated: City = Haines City, Postal Code = 33836
# Row 20686 updated: City = Marble Falls, Postal Code = 78654
# Row 20544 updated: City = San Antonio, Postal Code = 78237
# Row 20682 updated: City = San Antonio, Postal Code = 78251
# Row 20691 updated: City = San Antonio, Postal Code = 78210
# Row 20685 updated: City = San Antonio, Postal Code = 78229
# Row 20703 updated: City = Wichita Falls, Postal Code = 76309
# Row 20699 updated: City = El Paso, Postal Code = 79925
# Row 20671 updated: City = Delray Beach, Postal Code = 33483
# Row 20621 updated: City = Tyler, Postal Code = 75703
# Row 20717 updated: City = None, Postal Code = 23786
# Row 20719 updated: City = None, Postal Code = 32836
# Row 20716 updated: City = Orlando, Postal Code = 32819
# Row 20720 updated: City = San Antonio, Postal Code = 78221
# Row 20689 updated: City = Selma, Postal Code = 78154
# Row 20663 updated: City = El Paso, Postal Code = 79915
# Row 20726 updated: City = Jacksonville, Postal Code = 32246
# Row 20727 updated: City = Denison, Postal Code = 75020
# Row 20712 updated: City = Austin, Postal Code = 78703
# Row 20688 updated: City = San Antonio, Postal Code = 78223
# Row 20746 updated: City = Old Town Spring, Postal Code = 77380
# Row 20743 updated: City = Capitola, Postal Code = 95010
# Row 20673 updated: City = Orlando, Postal Code = 32819
# Row 20752 updated: City = Sunrise, Postal Code = 33313
# Row 20681 updated: City = San Antonio, Postal Code = 78240
# Row 20757 updated: City = Pembroke Pines, Postal Code = 33027
# Row 20747 updated: City = City of New York, Postal Code = 11201
# Row 20766 updated: City = Panama City Beach, Postal Code = 32407
# Row 20725 updated: City = Haines City, Postal Code = 33844
# Row 20715 updated: City = Jacksonville Beach, Postal Code = 32250
# Row 20755 updated: City = Sunrise, Postal Code = 33323
# Row 20765 updated: City = None, Postal Code = 33183
# Row 20724 updated: City = None, Postal Code = 34747
# Row 20771 updated: City = Jacksonville, Postal Code = 32246
# Row 20772 updated: City = Jacksonville, Postal Code = 32205
# Row 20731 updated: City = San Marcos, Postal Code = 78666
# Row 20776 updated: City = None, Postal Code = 77449
# Row 20781 updated: City = Houston, Postal Code = 77076
# Row 20794 updated: City = Austin, Postal Code = 78705
# Row 20774 updated: City = Laredo, Postal Code = 78045
# Row 20797 updated: City = Austin, Postal Code = 78705
# Row 20693 updated: City = San Antonio, Postal Code = 78222
# Row 20745 updated: City = San Antonio, Postal Code = 78204
# Row 20784 updated: City = Laredo, Postal Code = 78043
# Row 20804 updated: City = Buena Park, Postal Code = 90620
# Row 20763 updated: City = South Miami, Postal Code = 33143
# Row 20786 updated: City = Laredo, Postal Code = 78041
# Row 20822 updated: City = Jupiter, Postal Code = 33458
# Row 20768 updated: City = Panama City, Postal Code = 32401
# Row 20841 updated: City = West Palm Beach, Postal Code = 33405
# Row 20775 updated: City = Laredo, Postal Code = 78045
# Row 20842 updated: City = Boynton Beach, Postal Code = 33436
# Row 20812 updated: City = Dallas, Postal Code = 75226
# Row 20853 updated: City = Trinity, Postal Code = 34655
# Row 20834 updated: City = Fort Worth, Postal Code = 76164
# Row 20860 updated: City = Sanford, Postal Code = 32773
# Row 20821 updated: City = Jupiter, Postal Code = 33458
# Row 20864 updated: City = Palm Coast, Postal Code = 32137
# Row 20861 updated: City = Jacksonville, Postal Code = 32205
# Row 20871 updated: City = Riverside, Postal Code = 92521
# Row 20805 updated: City = Austin, Postal Code = 78705
# Row 20873 updated: City = Visalia, Postal Code = 93291
# Row 20868 updated: City = Visalia, Postal Code = 93291
# Row 20872 updated: City = Visalia, Postal Code = 93291
# Row 20891 updated: City = Jacksonville, Postal Code = 32246
# Row 20800 updated: City = Austin, Postal Code = 78756
# Row 20856 updated: City = Tarpon Springs, Postal Code = 34689
# Row 20889 updated: City = Jacksonville, Postal Code = 32254
# Row 20904 updated: City = San Andreas, Postal Code = 95249
# Row 20907 updated: City = Old Town Spring, Postal Code = 77389
# Row 20908 updated: City = Folsom, Postal Code = 95662
# Row 20862 updated: City = Jacksonville, Postal Code = 32260
# Row 20912 updated: City = None, Postal Code = 95762
# Row 20925 updated: City = San Antonio, Postal Code = 78255
# Row 20903 updated: City = Modesto, Postal Code = 95350
# Row 20835 updated: City = Fort Worth, Postal Code = 76164
# Row 20881 updated: City = None, Postal Code = 77047
# Row 20947 updated: City = Santa Ana, Postal Code = 92706
# Row 20828 updated: City = None, Postal Code = 34746
# Row 20921 updated: City = Kingsville, Postal Code = 78363
# Row 20830 updated: City = Harrisburg, Postal Code = 17103
# Row 20867 updated: City = Tracy, Postal Code = 95304
# Row 20926 updated: City = San Francisco, Postal Code = 94158
# Row 20960 updated: City = Scranton, Postal Code = 18509
# Row 21008 updated: City = Palm Springs, Postal Code = 92262
# Row 20927 updated: City = Round Rock, Postal Code = 78665
# Row 20923 updated: City = Anaheim, Postal Code = 92804
# Row 21012 updated: City = Town of Cortlandt, Postal Code = 10547
# Row 20973 updated: City = Miami Beach, Postal Code = 33139
# Row 20906 updated: City = Spring, Postal Code = 77373
# Row 21042 updated: City = Frisco, Postal Code = 75034
# Row 20961 updated: City = Dunmore, Postal Code = 18512
# Row 20988 updated: City = Brandon, Postal Code = 33569
# Row 20991 updated: City = None, Postal Code = 33566
# Row 21040 updated: City = Euless, Postal Code = 76040
# Row 21009 updated: City = Los Angeles, Postal Code = 90028
# Row 21047 updated: City = Highland Village, Postal Code = 75077
# Row 20943 updated: City = Spring Hill, Postal Code = 34606
# Row 21049 updated: City = Carrollton, Postal Code = 75287
# Row 21070 updated: City = Atascadero, Postal Code = 93422
# Row 21059 updated: City = Copiague, Postal Code = 11757
# Row 21075 updated: City = Walnut Creek, Postal Code = 94597
# Row 21072 updated: City = Grass Valley, Postal Code = 95949
# Row 21073 updated: City = Nevada City, Postal Code = 95959
# Row 21080 updated: City = Fresno, Postal Code = 93710
# Row 21062 updated: City = None, Postal Code = 33414
# Row 21086 updated: City = Vista, Postal Code = 92083
# Row 21026 updated: City = San Francisco, Postal Code = 94114
# Row 21092 updated: City = Fresno, Postal Code = 93740
# Row 21083 updated: City = Fresno, Postal Code = 93703
# Row 21111 updated: City = Del Rio, Postal Code = 78840
# Row 21087 updated: City = Cameron Park, Postal Code = 95682
# Row 21085 updated: City = Fresno, Postal Code = 93703
# Row 21058 updated: City = East Patchogue, Postal Code = 11772
# Row 21118 updated: City = Lodi, Postal Code = 95240
# Row 21079 updated: City = Pittsburg, Postal Code = 94565
# Row 21113 updated: City = Pismo Beach, Postal Code = 93449
# Row 21133 updated: City = Pleasant Hill, Postal Code = 94597
# Row 21119 updated: City = Galt, Postal Code = 95638
# Row 21122 updated: City = Eagle Pass, Postal Code = 78852
# Row 21139 updated: City = Chico, Postal Code = 95928
# Row 21120 updated: City = Eagle Pass, Postal Code = 78852
# Row 21074 updated: City = Antioch, Postal Code = 94509
# Row 21071 updated: City = San Luis Obispo, Postal Code = 93401
# Row 21149 updated: City = Houston, Postal Code = 77002
# Row 21150 updated: City = Houston, Postal Code = 77006
# Row 20971 updated: City = Wesley Chapel, Postal Code = 33544
# Row 21101 updated: City = Monterey Park, Postal Code = 90022
# Row 21153 updated: City = Tracy, Postal Code = 95304
# Row 21140 updated: City = Yuba City, Postal Code = 95991
# Row 21159 updated: City = South San Francisco, Postal Code = 94066
# Row 21136 updated: City = Sacramento, Postal Code = 95821
# Row 21141 updated: City = Red Bluff, Postal Code = 96080
# Row 21152 updated: City = Bellaire, Postal Code = 77401
# Row 21142 updated: City = Red Bluff, Postal Code = 96080
# Row 21184 updated: City = San Francisco, Postal Code = 94132
# Row 21172 updated: City = None, Postal Code = 77095
# Row 21204 updated: City = City of New York, Postal Code = 10019
# Row 21203 updated: City = City of New York, Postal Code = 10025
# Row 21154 updated: City = Brentwood, Postal Code = 94513
# Row 21207 updated: City = San Diego, Postal Code = 92101
# Row 21082 updated: City = Fresno, Postal Code = 93705
# Row 21206 updated: City = City of New York, Postal Code = 10013
# Row 21185 updated: City = Houston, Postal Code = 77099
# Row 21115 updated: City = Mountain View, Postal Code = 94041
# Row 21215 updated: City = Erie, Postal Code = 16501
# Row 21209 updated: City = City of New York, Postal Code = 10010
# ...
# Row 24857 updated: City = Saint Augustine Beach, Postal Code = 32084
# Row 24865 updated: City = Oviedo, Postal Code = 32765
# Row 24813 updated: City = City of New York, Postal Code = 11236
# Row 24819 updated: City = Jacksonville, Postal Code = 32216
# Row 24872 updated: City = Fort Myers Beach, Postal Code = 33913
# Row 24847 updated: City = City of New York, Postal Code = 10024
# Row 24835 updated: City = City of New York, Postal Code = 10075
# Row 24889 updated: City = Haines City, Postal Code = 33844
# Row 24890 updated: City = Jacksonville, Postal Code = 32258
# Row 24894 updated: City = Buffalo, Postal Code = 14220
# Row 24888 updated: City = Hialeah, Postal Code = 33018
# Row 24896 updated: City = Orlando, Postal Code = 32819
# Row 24898 updated: City = Tampa, Postal Code = 33614
# Row 24837 updated: City = City of New York, Postal Code = 10024
# Row 24908 updated: City = Jacksonville, Postal Code = 32246
# Row 24836 updated: City = Philadelphia, Postal Code = 19120
# Row 24691 updated: City = Town of Colonie, Postal Code = 12205
# Row 24913 updated: City = Orlando, Postal Code = 32801
# Row 24893 updated: City = Lakeland, Postal Code = 33805
# Row 24855 updated: City = Miami, Postal Code = 33130
# Row 24887 updated: City = None, Postal Code = 32653
# Row 24911 updated: City = Cape Canaveral, Postal Code = 32920
# Row 24910 updated: City = City of New York, Postal Code = 10011
# Row 24905 updated: City = City of Batavia, Postal Code = 14020
# Row 24922 updated: City = City of New York, Postal Code = 10016
# Row 24923 updated: City = Gainesville, Postal Code = 32601
# Row 24895 updated: City = Buffalo, Postal Code = 14222
# Row 24920 updated: City = Pensacola, Postal Code = 32504
# Row 24925 updated: City = Jupiter, Postal Code = 33477
# Row 24918 updated: City = Bradenton, Postal Code = 34209
# Row 24927 updated: City = Pine Island, Postal Code = 33324
# Row 24928 updated: City = City of New York, Postal Code = 11238
# Row 24924 updated: City = Winter Park, Postal Code = 32789
# Row 24931 updated: City = Fort Myers, Postal Code = 33907
# Row 24932 updated: City = Wildwood, Postal Code = 34484
# Row 24939 updated: City = Tampa, Postal Code = 33615
# Row 24946 updated: City = Village of Wellsville, Postal Code = 14895
# Row 24933 updated: City = City of New York, Postal Code = 11372
# Row 24926 updated: City = City of New York, Postal Code = 10017
# Row 24973 updated: City = Aventura, Postal Code = 33180
# Row 24919 updated: City = City of Rochester, Postal Code = 14624
# Row 24929 updated: City = Orlando, Postal Code = 32809
# Row 24995 updated: City = Deer Park, Postal Code = 11729
# Row 25001 updated: City = North New Hyde Park, Postal Code = 11040
# Row 24917 updated: City = Palmetto, Postal Code = 34221
# Row 24994 updated: City = Lakeland, Postal Code = 33811
# Row 24825 updated: City = Port Richey, Postal Code = 34668
# Row 24891 updated: City = Kissimmee, Postal Code = 34759
# Row 24916 updated: City = Butler, Postal Code = 16001
# Row 25000 updated: City = East Meadow, Postal Code = 11554
# Row 24961 updated: City = Jacksonville Beach, Postal Code = 32250
# Row 24968 updated: City = City of New York, Postal Code = 11201
# Row 25011 updated: City = None, Postal Code = 33144
# Row 25010 updated: City = Orlando, Postal Code = 32819
# Row 25035 updated: City = Village of Lake George, Postal Code = 12845
# Row 25037 updated: City = Jacksonville, Postal Code = 32207
# Row 25042 updated: City = Aventura, Postal Code = 33180
# Row 25003 updated: City = None, Postal Code = 33897
# Row 25046 updated: City = Miami, Postal Code = 33137
# Row 25036 updated: City = Saint Petersburg, Postal Code = 33702
# Row 25048 updated: City = Miami Gardens, Postal Code = 33056
# Row 25061 updated: City = Sarasota, Postal Code = 34239
# Row 25045 updated: City = Miami, Postal Code = 33127
# Row 25052 updated: City = City of Little Falls, Postal Code = 13365
# Row 25053 updated: City = Largo, Postal Code = 33771
# Row 24921 updated: City = Ormond Beach, Postal Code = 32174
# Row 25049 updated: City = Hialeah, Postal Code = 33012
# Row 25051 updated: City = Clearwater, Postal Code = 33765
# Row 25002 updated: City = Saint Augustine, Postal Code = 32084
# Row 25080 updated: City = Seminole, Postal Code = 33744
# Row 25101 updated: City = Hollywood, Postal Code = 33022
# Row 25082 updated: City = Treasure Island, Postal Code = 33706
# Row 25050 updated: City = Hialeah, Postal Code = 33013
# Row 25083 updated: City = Miami Beach, Postal Code = 33139
# Row 25091 updated: City = Winter Haven, Postal Code = 33884
# Row 25092 updated: City = Winter Haven, Postal Code = 33880
# Row 25118 updated: City = Pocono Township, Postal Code = 18372
# Row 25123 updated: City = None, Postal Code = 12601
# Row 25117 updated: City = Jackson Township, Postal Code = 18372
# Row 25130 updated: City = City of New York, Postal Code = 11215
# Row 25127 updated: City = City of New York, Postal Code = 11364
# Row 25128 updated: City = Oyster Bay, Postal Code = 11771
# Row 25126 updated: City = Islip, Postal Code = 11751
# Row 25084 updated: City = None, Postal Code = 32819
# Row 25116 updated: City = Pocono Township, Postal Code = 18372
# Row 25135 updated: City = Nanuet, Postal Code = 10954
# Row 25133 updated: City = Tampa, Postal Code = 33617
# Row 25129 updated: City = Town of Brookhaven, Postal Code = 11720
# Row 25134 updated: City = None, Postal Code = 32816
# Row 25098 updated: City = Lake City, Postal Code = 32055
# Row 25140 updated: City = City of New York, Postal Code = 10011
# Row 25138 updated: City = City of New York, Postal Code = 10017
# Row 25145 updated: City = None, Postal Code = 13820
# Row 25006 updated: City = Town of Amherst, Postal Code = 14226
# Row 25143 updated: City = None, Postal Code = 16214
# Row 25139 updated: City = City of New York, Postal Code = 10016
# Row 25149 updated: City = Jacksonville, Postal Code = 32277
# Row 25131 updated: City = City of New York, Postal Code = 11418
# Row 25142 updated: City = None, Postal Code = 16214
# Row 25155 updated: City = Pensacola, Postal Code = 32503
# Row 25151 updated: City = Wilton Manors, Postal Code = 33334
# Row 25160 updated: City = Village of Rockville Centre, Postal Code = 11570
# Row 25157 updated: City = City of New York, Postal Code = 10032
# Row 25162 updated: City = Franklin Square, Postal Code = 11010
# Row 25132 updated: City = Temple Terrace, Postal Code = 33617
# Row 25136 updated: City = City of New York, Postal Code = 10016
# Row 25161 updated: City = City of Kingston, Postal Code = 12401
# Row 25164 updated: City = City of Long Beach, Postal Code = 11561
# Row 25137 updated: City = City of New York, Postal Code = 10016
# Row 25167 updated: City = City of Long Beach, Postal Code = 11561
# Row 25153 updated: City = Miami, Postal Code = 33127
# Row 25166 updated: City = Huntington, Postal Code = 11743
# Row 25168 updated: City = Village of Island Park, Postal Code = 11558
# Row 25163 updated: City = City of Long Beach, Postal Code = 11561
# Row 25165 updated: City = City of Long Beach, Postal Code = 11561
# Row 25154 updated: City = Pensacola, Postal Code = 32505
# Row 25170 updated: City = Point Lookout, Postal Code = 11569
# Row 25171 updated: City = Wantagh, Postal Code = 11793
# Row 25146 updated: City = Lady Lake, Postal Code = 32159
# Row 25159 updated: City = Town of Saugerties, Postal Code = 12477
# Row 25181 updated: City = Melbourne, Postal Code = 32910
# Row 25172 updated: City = City of Long Beach, Postal Code = 11561
# Row 25183 updated: City = Viera, Postal Code = 32940
# Row 25169 updated: City = Oceanside, Postal Code = 11572
# Row 25176 updated: City = Cocoa, Postal Code = 32955
# Row 25179 updated: City = Rockledge, Postal Code = 32922
# Row 25175 updated: City = Daytona Beach, Postal Code = 32118
# Row 25185 updated: City = Rockledge, Postal Code = 32922
# Row 25186 updated: City = Cocoa, Postal Code = 32955
# Row 25188 updated: City = Cocoa, Postal Code = 32922
# Row 25100 updated: City = Village of Stamford, Postal Code = 12167
# Row 25191 updated: City = Cocoa, Postal Code = 32926
# Row 25180 updated: City = Rockledge, Postal Code = 32955
# Row 25194 updated: City = Palm Bay, Postal Code = 32909
# Row 25184 updated: City = Rockledge, Postal Code = 32955
# Row 25193 updated: City = Orlando, Postal Code = 32839
# Row 25189 updated: City = Cocoa, Postal Code = 32922
# Row 25182 updated: City = Viera, Postal Code = 32940
# Row 25198 updated: City = Palm Bay, Postal Code = 32905
# Row 25200 updated: City = Village of Dryden, Postal Code = 13053
# Row 25190 updated: City = Cocoa, Postal Code = 32922
# Row 25177 updated: City = Merritt Island, Postal Code = 32952
# Row 25197 updated: City = Melbourne, Postal Code = 32934
# Row 25199 updated: City = Palm Bay, Postal Code = 32907
# Row 25203 updated: City = Naples, Postal Code = 34103
# Row 25201 updated: City = City of New York, Postal Code = 10013
# Row 25207 updated: City = Fort Pierce, Postal Code = 34947
# Row 25206 updated: City = Fort Pierce, Postal Code = 34947
# Row 25192 updated: City = Cocoa, Postal Code = 32922
# Row 25208 updated: City = Florida Ridge, Postal Code = 32962
# Row 25195 updated: City = Palm Bay, Postal Code = 32905
# Row 25209 updated: City = Fort Pierce, Postal Code = 34950
# Row 25216 updated: City = Town of Smithtown, Postal Code = 11754
# Row 25178 updated: City = Rockledge, Postal Code = 32955
# Row 25214 updated: City = Fort Lauderdale, Postal Code = 33301
# Row 25215 updated: City = Commack, Postal Code = 11725
# Row 25218 updated: City = Commack, Postal Code = 11725
# Row 25221 updated: City = Elwood, Postal Code = 11731
# Row 25204 updated: City = Sarasota, Postal Code = 34230
# Row 25227 updated: City = City of New York, Postal Code = 10013
# Row 25226 updated: City = City of New York, Postal Code = 10003
# Row 25229 updated: City = City of New York, Postal Code = 11231
# Row 25210 updated: City = Fort Pierce, Postal Code = 34947
# Row 25228 updated: City = City of New York, Postal Code = 10016
# Row 25205 updated: City = Fort Pierce, Postal Code = 34947
# Row 25217 updated: City = Town of Smithtown, Postal Code = 11754
# Row 25234 updated: City = City of New York, Postal Code = 10017
# Row 25219 updated: City = Commack, Postal Code = 11725
# Row 25220 updated: City = Boca Raton, Postal Code = 33431
# Row 25236 updated: City = City of Schenectady, Postal Code = 12303
# Row 25230 updated: City = City of New York, Postal Code = 10016
# Row 25237 updated: City = None, Postal Code = 12053
# Row 25235 updated: City = City of Utica, Postal Code = 13501
# Row 25232 updated: City = City of New York, Postal Code = 11354
# Row 25242 updated: City = Troy, Postal Code = 12180
# Row 25231 updated: City = City of New York, Postal Code = 10009
# Row 25196 updated: City = Palm Bay, Postal Code = 32907
# Row 25240 updated: City = Ticonderoga, Postal Code = 12883
# Row 25243 updated: City = City of Albany, Postal Code = 12207
# Row 25245 updated: City = Town of Colonie, Postal Code = 12110
# Row 25244 updated: City = None, Postal Code = 12442
# Row 25241 updated: City = City of Amsterdam, Postal Code = 12010
# Row 25233 updated: City = City of New York, Postal Code = 10018
# Row 25251 updated: City = Saint Augustine Beach, Postal Code = 32080
# Row 25252 updated: City = Williston, Postal Code = 32696
# Row 25211 updated: City = Port Saint Lucie, Postal Code = 34986
# Row 25250 updated: City = None, Postal Code = 32606
# Row 25238 updated: City = City of Schenectady, Postal Code = 12305
# Row 25249 updated: City = Saint Augustine Beach, Postal Code = 32080
# Row 25255 updated: City = Newberry, Postal Code = 32669
# Row 25239 updated: City = Village of Ballston Spa, Postal Code = 12020
# Row 25246 updated: City = High Springs, Postal Code = 32643
# Row 25258 updated: City = Wantagh, Postal Code = 11793
# Row 25247 updated: City = City of Albany, Postal Code = 12208
# Row 25248 updated: City = Town of New Scotland, Postal Code = 12159
# Row 25257 updated: City = Clearwater, Postal Code = 33767
# Row 25187 updated: City = Titusville, Postal Code = 32780
# Row 25267 updated: City = None, Postal Code = 32550
# Row 25262 updated: City = Saint Augustine Beach, Postal Code = 32080
# Row 25268 updated: City = Alys Beach, Postal Code = 32461
# Row 25259 updated: City = Seaford, Postal Code = 11783
# Row 25253 updated: City = None, Postal Code = 32669
# Row 25272 updated: City = City of Ithaca, Postal Code = 14850
# Row 25270 updated: City = Shamokin Dam, Postal Code = 17876
# Row 25274 updated: City = Ocoee, Postal Code = 34734
# Row 25269 updated: City = Port Saint Lucie, Postal Code = 34987
# Row 25260 updated: City = Hanover, Postal Code = 17331
# Row 25256 updated: City = Treasure Island, Postal Code = 33785
# Row 25277 updated: City = None, Postal Code = 15009
# Row 25261 updated: City = Paradise Township, Postal Code = 17364
# Row 25280 updated: City = Monaca, Postal Code = 15061
# Row 25279 updated: City = New Brighton, Postal Code = 15066
# Row 25264 updated: City = Pompano Beach, Postal Code = 33064
# Row 25278 updated: City = Chippewa Township, Postal Code = 15010
# Row 25292 updated: City = West Fallowfield Township, Postal Code = 19330
# Row 25282 updated: City = Cranberry Township, Postal Code = 16066
# Row 25294 updated: City = Riverhead, Postal Code = 11901
# Row 25295 updated: City = Calverton, Postal Code = 11901
# Row 25296 updated: City = Downingtown, Postal Code = 19335
# Row 25288 updated: City = Town of Smithtown, Postal Code = 11779
# Row 25263 updated: City = Miami, Postal Code = 33127
# Row 25290 updated: City = Commack, Postal Code = 11725
# Row 25298 updated: City = Lower Oxford Township, Postal Code = 19363
# Row 25281 updated: City = Beaver Falls, Postal Code = 15010
# Row 25299 updated: City = Riverhead, Postal Code = 11901
# Row 25303 updated: City = Pensacola, Postal Code = 32526
# Row 25304 updated: City = Ensley, Postal Code = 32534
# Row 25305 updated: City = Pensacola, Postal Code = 32534
# Row 25254 updated: City = None, Postal Code = 32669
# Row 25273 updated: City = Orlando, Postal Code = 32803
# Row 25300 updated: City = Milton, Postal Code = 32570
# Row 25297 updated: City = Downingtown, Postal Code = 19335
# Row 25310 updated: City = Pensacola, Postal Code = 32514
# Row 25309 updated: City = Pensacola, Postal Code = 32504
# Row 25302 updated: City = Ensley, Postal Code = 32533
# Row 25301 updated: City = Pensacola, Postal Code = 32534
# Row 25308 updated: City = Pensacola, Postal Code = 32534
# Row 25306 updated: City = Pensacola, Postal Code = 32504
# Row 25313 updated: City = None, Postal Code = 32836
# Row 25333 updated: City = Orlando, Postal Code = 32804
# Row 25293 updated: City = Riverhead, Postal Code = 11901
# Row 25332 updated: City = Orlando, Postal Code = 32803
# Row 25334 updated: City = Orlando, Postal Code = 32803
# Row 25336 updated: City = Orlovista, Postal Code = 32818
# Row 25339 updated: City = Orlando, Postal Code = 32806
# Row 25326 updated: City = Campbell, Postal Code = 34758
# Row 25291 updated: City = Upper Merion Township, Postal Code = 19406
# Row 25348 updated: City = City of New York, Postal Code = 10010
# Row 25325 updated: City = Buffalo, Postal Code = 14217
# Row 25337 updated: City = Orlovista, Postal Code = 32818
# Row 25289 updated: City = East Lampeter Township, Postal Code = 17602
# Row 25307 updated: City = Pensacola, Postal Code = 32502
# Row 25347 updated: City = City of New York, Postal Code = 11216
# Row 25351 updated: City = None, Postal Code = 12901
# Row 25823 updated: City = City of New York, Postal Code = 11354
# Row 25666 updated: City = City of New York, Postal Code = 10012
# Row 25311 updated: City = Pensacola, Postal Code = 32502
# Row 25335 updated: City = Orlando, Postal Code = 32835
# Row 25361 updated: City = Wilkes-Barre, Postal Code = 18705
# Row 26793 updated: City = Garden City South, Postal Code = 11552
# Row 26338 updated: City = City of New York, Postal Code = 11361
# Row 25338 updated: City = Orlando, Postal Code = 32801
# Row 25360 updated: City = Wilkes-Barre, Postal Code = 18701
# Row 25358 updated: City = Wilkes-Barre, Postal Code = 18702
# Row 26063 updated: City = Merrick, Postal Code = 11566
# Row 26428 updated: City = None, Postal Code = 16201
# Row 25607 updated: City = City of New York, Postal Code = 11215
# Row 26193 updated: City = City of New York, Postal Code = 11236
# Row 25346 updated: City = City of New York, Postal Code = 11233

# %%
# check rows that still have missing values
rows_with_missing_values = df_restaurant_clean[df_restaurant_clean['city'].isnull() | df_restaurant_clean['postal_code'].isnull()]
rows_with_missing_values
# Out:
#                             name  \
# 1648               Horseshoe Inn
# 5249            UN1QUE TEA & BAR
# 7362       Redland Ballfield BBQ
# 7779              Smile Market 2
# 14386          Yummy Pho & Grill
# 15905                        炭香村
# 18275              P.J. Clarke's
# 18883                Chuck Wagon
# 19965  Amigos Mexican Restaurant
# 20313        Mastro's Ocean Club
# 22434              Chifa Du Kang
# 23661             Little Beijing
# 24195                     Hoss's
# 26428                Asian Green
#
#                                                  address         state  \
# 1648       Horseshoe Inn, W Perimeter Rd, Coldspring, NY      New York
# 5249   California, Hacienda Heights, S Hacienda Blvd,...    California
# 7362   Redland Ballfield BBQ, hwy 64 & VZ County Road...         Texas
# 7779   95827 California, Sacramento, Folsom Blvd, Smi...    California
# 14386  Texas, Spring, Kuykendahl Rd, Yummy Pho & Gril...         Texas
# 15905  〒91748 California, Rowland Heights, Colima Rd,...    California
# 18275  P.J. Clarke's, 250 Vesey St, New York, NY 1028...      New York
# 18883  Chuck Wagon, 1203 Academy Ave, Sanger, CA 9365...    California
# 19965  Amigos Mexican Restaurant, 285 N Main St, Bish...    California
# 20313  Mastro's Ocean Club, 18412 Pacific Coast Hwy, ...    California
# 22434  United States, Florida, Miami, SW 40th St, Chi...       Florida
# 23661  Little Beijing, 1420 Beaumont Ave, Beaumont, C...    California
# 24195  Hoss's, 4308 Business 220, Bedford, PA 15522, ...  Pennsylvania
# 26428  Pennsylvania, Kittanning, Franklin Village Mal...  Pennsylvania
#
#                    city postal_code   latitude   longitude  avg_rating  \
# 1648                NaN       14738  42.055410  -78.938788         4.9
# 5249                NaN       91745  33.995150 -117.966782         4.5
# 7362                NaN         NaN  32.378490  -95.503570         4.7
# 7779                NaN       95827  38.571112 -121.340102         4.8
# 14386               NaN       77389  30.113487  -95.552523         4.6
# 15905               NaN       91748  33.987030 -117.894920         4.1
# 18275  City of New York         NaN  40.713711  -74.016239         4.2
# 18883            Sanger         NaN  36.699852 -119.554766         4.6
# 19965            Bishop         NaN  37.362931 -118.395612         4.2
# 20313           Topanga         NaN  34.039687 -118.576133         4.5
# 22434               NaN       33165  25.733263  -80.355566         4.5
# 23661          Beaumont         NaN  33.947794 -116.975985         4.4
# 24195  Bedford Township         NaN  40.051369  -78.510567         4.2
# 26428               NaN       16201  40.813485  -79.549444         3.0
#
#        num_of_reviews  price_numeric                                gmap_id
# 1648               18              0  0x89d29fd67c9bc79b:0xb6c8a298729a5333
# 5249               58              0  0x80c2d5f8c0b01c57:0xa4f968b7b3666706
# 7362               36              0  0x8649b0e69f9442ef:0x40a536f0bde607d3
# 7779               17              0  0x809add2c297d2171:0x251dd1d6afd0a4e5
# 14386              58              0  0x864733fa1d17774b:0x396f849380fd56b4
# 15905              28              0  0x80c32af6815467e5:0x2c68b44b22cc06b9
# 18275            1684              2  0x89c25a1b0cd3c8cb:0xe29a00ff230959b8
# 18883            1118              1  0x8094f90050be4dcb:0x8a52470b825bc0f3
# 19965             276              1  0x80be3dffaf1721d3:0x85df382562b75703
# 20313            1297              4  0x80c2a3e3c883c457:0xae5fd9b1d21d56ae
# 22434             988              2  0x88d9b8afe2442fdf:0x5bddff88e7c19e36
# 23661             137              1  0x80db44cec54fbe4f:0x682c8ce6161e7c98
# 24195            1104              2  0x89ca52d06cb4121b:0x33736af1c5a6aa31
# 26428              63              0  0x883357e4d528eebb:0x9c150fac62c473b2

# %%
df_restaurant_clean['city'] = df_restaurant_clean['city'].str.replace(r'^City of\s+', '', regex=True)

# %%
df_restaurant_clean['postal_code'] = df_restaurant_clean['postal_code'].fillna('00000')
df_restaurant_clean['city'] = df_restaurant_clean['city'].fillna('No Data')

# %%
# Rename the column 'name' to 'restaurant_name'
df_restaurant_clean = df_restaurant_clean.rename(columns={'name': 'restaurant_name'})

# %%
df_restaurant_clean.head()
# Out:
#               restaurant_name  \
# 0                San Soo Dang
# 1                Vons Chicken
# 2               Golden Castle
# 3             Oneyda's Bakery
# 4  Top Cat Seafood Restaurant
#
#                                              address       state         city  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  California  Los Angeles
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...  California    La Mirada
# 2    Golden Castle, 1906 E 12th St, Austin, TX 78702       Texas       Austin
# 3  Oneyda's Bakery, 600 Goodlette-Frank Rd #101, ...     Florida       Naples
# 4  Top Cat Seafood Restaurant, 3117 Martin Luther...       Texas       Dallas
#
#    postal_code   latitude   longitude  avg_rating  num_of_reviews  \
# 0        90005  34.058092 -118.292130         4.4              18
# 1        90638  33.916402 -118.010855         4.5              18
# 2        78702  30.273985  -97.719563         4.5               8
# 3        34102  26.154754  -81.790528         4.6              19
# 4        75215  32.773130  -96.764484         3.9               8
#
#    price_numeric                                gmap_id
# 0              0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1              0  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 2              0  0x8644b59b8fe872e5:0x5e638876caa84cc3
# 3              1  0x88dae191ee505917:0x6ba3e25388d3fad4
# 4              0  0x864e9891e381f3df:0x4cefe6219bc9199c

# %%
missing_values_count = df_restaurant_clean.isnull().sum()
print("Count of missing values in each column:")
print(missing_values_count)
# Out:
# Count of missing values in each column:
# restaurant_name    0
# address            0
# state              0
# city               0
# postal_code        0
# latitude           0
# longitude          0
# avg_rating         0
# num_of_reviews     0
# price_numeric      0
# gmap_id            0
# dtype: int64

# %% [markdown]
# **Data Type Conversions**
# - Most of them were correct and so onnly postal_code was changed from an `Object` to an `Int`

# %%
df_restaurant_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26686 entries, 0 to 26913
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant_name  26686 non-null  object
#  1   address          26686 non-null  object
#  2   state            26686 non-null  object
#  3   city             26686 non-null  object
#  4   postal_code      26686 non-null  int32
#  5   latitude         26686 non-null  float64
#  6   longitude        26686 non-null  float64
#  7   avg_rating       26686 non-null  float64
#  8   num_of_reviews   26686 non-null  int64
#  9   price_numeric    26686 non-null  int32
#  10  gmap_id          26686 non-null  object
# dtypes: float64(3), int32(2), int64(1), object(5)
# memory usage: 3.2+ MB

# %%
try:
    df_restaurant_clean['postal_code'] = df_restaurant_clean['postal_code'].astype(int)
except ValueError as e:
    print(f"Conversion error: {e}")
    print("Postal codes might contain non-numeric values or NaNs.")

# %% [markdown]
# ## Loading/Saving Transformed Data
#
# After the data has been cleaned and transformed, it's crucial to save it in a structured and accessible format for future analysis or processing. The steps below outline how the data is saved:
#
# ### Preparation for Saving
# - **Base Save Path**: A base directory (`../data/Processed/`) is defined to store the processed files. This helps in organizing the output data systematically.
#
# ### Saving Dataframes
# - **File Paths**: The full paths for saving the files are defined, incorporating the base path and the desired filenames (`google_restaurant_clean.parquet` for the cleaned restaurant data and `google_restaurant_cat_dummies.parquet` for the category dummies).
# - **Parquet Format**: The data is saved in Parquet format, a columnar storage file format optimized for speed in both reading and writing, as well as efficient data compression and encoding schemes. This choice is particularly suitable for handling large datasets like this one.
# - **Dataframe Saving**: The `to_parquet` method is used to save `df_restaurant_clean` and `restaurant_cat_dummies` dataframes to their respective file paths. The `index=False` parameter is specified to avoid saving dataframe indices, keeping the files lean and focused on the data content.
#
# By saving the transformed data in a structured and efficient format, we ensure that it is readily accessible for future analyses, providing a solid foundation for insights and decision-making.

# %%
save_path = '../data/Processed/'

os.makedirs(save_path, exist_ok=True)

clean_file_path = save_path + 'google_restaurant_clean.parquet'
dummies_file_path = save_path + 'google_restaurant_cat_dummies.parquet'

df_restaurant_clean.to_parquet(clean_file_path, index=False)
restaurant_cat_dummies.to_parquet(dummies_file_path, index=False)
